# %%
# !python main.py \
  -g 0 -r 0\
  -N_p 5000 -i 5000 -b 16 -lr 1e-3 \
  -N_d 3000 -sm random \
  -dir ../data/sampled \
  --grid_path ../data/sampled/OccRpt0_N32768.npz \
  --w_occ 2.0 --w_field 1.0 --lambda_nf 1e-5
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
#
#
# Model Parameters:
# Device: cuda
# Run Number: 0
# Folder Name: DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random
# Iterations: 5000
# Batch Size: 16
# Learning Rate: 0.001
# Number of Samples: 3000
# Data Split Method: random
# Branch Condition Input Components: mlc
# Trunk Input Components: xyzd
# Output Components: xyzs
# Trunk Encoding Hidden Dimension: 128
# Branch Hidden Dimension: 128
# Trunk Hidden Dimension: 128
# Fully Connected Hidden Dimension: 128
# NF: num_flows=4, hidden=64, act=Tanh, lambda_nf=1e-05
# Loss weights: w_occ=2.0, w_field=1.0
#
#
# [DATA] Rpt: N_field=5000, Grid: Ng=32768, total N=37768
# branch_condition_input_train.shape = (2400, 5)
# branch_pointnet_input_train.shape = (2400, 5000, 3)
# trunk_input_train.shape = (2400, 37768, 4)
# ...

# %%
# !python generate_and_visualize_occ.py \
  --experiment_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --data_root ../data \
  --case_key ver_25_217 \
  --out_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/gen_outputs \
  --num_samples 8 \
  --grid_n 96 \
  --grid_extent 1.0 \
  --occ_thr 0.5 \
  --viz_component 3 \
  --device cuda:0
# Out:
# ### RUNNING FILE: /workspace/Point-DeepONet/99. FuckNet/generate_and_visualize_occ.py
# ...

# %%
import numpy as np
split = np.load("/workspace/Point-DeepONet/data/npy/combined_3000_split_random_train_valid.npz")
print(split["train"][:20])
# Out:
# ['hor_238_489' 'ver_25_217' 'ver_20_575' 'ver_19_519' 'hor_565_79'
#  'ver_371_125' 'hor_422_291' 'ver_625_434' 'dia_479_122' 'dia_375_291'
#  'ver_438_454' 'dia_10_30' 'ver_235_389' 'ver_449_114' 'ver_28_492'
#  'ver_289_30' 'hor_270_319' 'dia_321_576' 'dia_291_186' 'ver_182_417']

# %%
import os, pickle
exp = "../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random"
trunk_scaler = pickle.load(open(os.path.join(exp, "trunk_scaler.pkl"), "rb"))
print(trunk_scaler.data_min_[:3])
print(trunk_scaler.data_max_[:3])
# Out:
# [ -39.4494   -164.821      -0.598275]
# [72.98839 21.59231 65.77562]

# %%
print(torch.tensor(0.).device)
# Out:
# cpu
