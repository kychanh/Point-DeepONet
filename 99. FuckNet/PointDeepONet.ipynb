# %%
# !python main.py \
  -g 0 -r 0\
  -N_p 5000 -i 10000 -b 16 -lr 1e-3 \
  -N_d 3000 -sm random \
  -dir ../data/sampled \
  --grid_path ../data/sampled/OccRpt1_N262144.npz \
  --w_occ 2.0 --w_field 1.0 --lambda_nf 1e-5
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
#
#
# Model Parameters:
# Device: cuda
# Run Number: 0
# Folder Name: DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random
# Iterations: 10000
# Batch Size: 16
# Learning Rate: 0.001
# Number of Samples: 3000
# Data Split Method: random
# Branch Condition Input Components: mlc
# Trunk Input Components: xyzd
# Output Components: xyzs
# Trunk Encoding Hidden Dimension: 128
# Branch Hidden Dimension: 128
# Trunk Hidden Dimension: 128
# Fully Connected Hidden Dimension: 128
# NF: num_flows=4, hidden=64, act=Tanh, lambda_nf=1e-05
# Loss weights: w_occ=2.0, w_field=1.0
#
#
# [DATA] Rpt: N_field=5000, Grid: Ng=262144, total N=267144
# branch_condition_input_train.shape = (2400, 5)
# branch_pointnet_input_train.shape = (2400, 5000, 3)
# trunk_input_train.shape = (2400, 267144, 4)
# ...

# %%
# !python generate_and_visualize_occ.py \
  --experiment_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --data_root ../data \
  --case_key dia_19_95 \
  --out_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/gen_outputs \
  --num_samples 8 \
  --grid_n 96 \
  --grid_extent 1.0 \
  --occ_thr 0.5 \
  --viz_component 3 \
  --device cuda:0
# Out:
# ### RUNNING FILE: /workspace/Point-DeepONet/99. FuckNet/generate_and_visualize_occ.py
# ...

# %%
# !python eval_shape_decoder.py \
  --experiment_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random\
  --dir_base_load_data ../data/sampled \
  --volume_mesh_dir ../data/VolumeMesh \
  --RUN 0 \
  --N_pt 5000 \
  --N_samples 3000 \
  --split_method random \
  --num_cases 5 \
  --occ_thr 0.5 \
  --out_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/eval_outputs \
  --case_mode first \
  --grid_path ../data/sampled/OccRpt1_N262144.npz
# Out:
# ### RUNNING FILE: /workspace/Point-DeepONet/99. FuckNet/eval_shape_decoder.py
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# ...

# %%
import numpy as np
split = np.load("/workspace/Point-DeepONet/data/npy/combined_3000_split_random_train_valid.npz")
print(split["valid"][:20])
# Out:
# ['hor_456_9' 'hor_587_131' 'dia_147_418' 'ver_173_59' 'hor_78_81'
#  'hor_319_569' 'hor_438_448' 'dia_19_95' 'dia_592_61' 'hor_114_525'
#  'dia_545_290' 'ver_113_129' 'dia_77_81' 'dia_245_34' 'dia_533_485'
#  'hor_476_432' 'ver_415_14' 'dia_247_616' 'ver_284_378' 'ver_107_291']

# %%
# !python inverse_design_max_stress.py \
  --exp_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --xyzdmlc_path ../data/npy/xyzdmlc.npz \
  --case_key ver_415_14 \
  --n_iters 1000 \
  --n_restarts 8 \
  --target_vol_frac 0.18 \
  --lambda_stress 1e-2 \
  --lambda_vol 50 \
  --lambda_z 1e-2 \
  --stress_temperature 30.0 \
  --nx 96 --ny 96 --nz 96 \
  --save_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results \
  --save_name jeb_inverse_best.npz
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# ...

# %%
# !python render_inverse_trajectory.py \
  --experiment_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --trajectory_pkl /workspace/Point-DeepONet/experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_restart_2.pkl \
  --xyz_npz ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/jeb_inverse_best.npz \
  --case_key ver_415_14 \
  --out_dir /workspace/Point-DeepONet/experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results \
  --grid_n 48 \
  --occ_thr 0.5 \
  --xyzdmlc_path ../data/npy/xyzdmlc.npz \
  --viz_component 3 \
  --out_name mean_stress_2
# Out:
# ### RUNNING FILE: /workspace/Point-DeepONet/99. FuckNet/render_inverse_trajectory.py
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# [INFO] device = cuda:0
# ...

# %%
# !python eval_field_decoder.py \
  --experiment_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --data_root ../data \
  --volume_mesh_dir ../data/VolumeMesh \
  --num_cases 5 \
  --case_mode random \
  --component 1 \
  --out_path ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/eval_outputs/0_eval_field_compare.png
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# ...

# %%
# !python inverse_design_min_vol.py \
  --exp_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --xyzdmlc_path ../data/npy/xyzdmlc.npz \
  --case_key dia_592_61 \
  --field_component ux \
  --field_allow 0.3 \
  --use_abs_for_disp \
  --lambda_constraint 1e9 \
  --lambda_z 1\
  --n_iters 5000 --n_restarts 6 \
  --save_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# ...

# %%
# !python render_inverse_trajectory.py \
  --experiment_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --trajectory_pkl /workspace/Point-DeepONet/experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_5.pkl \
  --xyz_npz ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/inverse_best_vol.npz \
  --case_key dia_592_61 \
  --out_dir /workspace/Point-DeepONet/experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results \
  --grid_n 48 \
  --occ_thr 0.5 \
  --xyzdmlc_path ../data/npy/xyzdmlc.npz \
  --viz_component 0 \
  --out_name min_vol_ux_5_2 \
  --iters 0 50 100 200 500 1000 2000 3000 4000
# Out:
# ### RUNNING FILE: /workspace/Point-DeepONet/99. FuckNet/render_inverse_trajectory.py
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# [INFO] device = cuda:0
# ...

# %%
# !python render_multi_trajectory.py \
  --experiment_dir ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random \
  --xyz_npz ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/inverse_best_vol.npz \
  --case_key dia_592_61 \
  --out_dir /workspace/Point-DeepONet/experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results \
  --grid_n 96 \
  --occ_thr 0.5 \
  --xyzdmlc_path ../data/npy/xyzdmlc.npz \
  --viz_component 0 \
  --out_name min_vol_ux_all \
  --iters 0 50 100 200 500 1000 2000 3000 4000 \
  --trajectory_pkl ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_1.pkl\
    ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_2.pkl\
    ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_3.pkl\
    ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_4.pkl\
    ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_5.pkl\
    ../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_6.pkl\
    #../experiments/DesignGenNOStyle_OCC_RUN0_D3000_Npt5000_branch_mlc_trunk_xyzd_out_xyzs_split_random/inverse_results/trajectory_vol_restart_5.pkl\
# Out:
# ### RUNNING FILE: /workspace/Point-DeepONet/99. FuckNet/render_multi_trajectory.py
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# [INFO] device = cuda:0
# ...
