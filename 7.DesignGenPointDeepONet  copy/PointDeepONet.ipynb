# %%
# !python main.py --phase field -N_p 5000 -i 10000 -lr 1e-3
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
#
#
# Model Parameters:
# Device: cuda
# Phase: field
# Run Number: 0
# Folder Name: Changed2Phase_field_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random
# Iterations: 10000
# Batch Size: 16
# Learning Rate: 0.001
# Number of Samples: 3000
# Data Split Method: random
# Branch Condition Input Components: mlc
# Trunk Input Components: xyzd
# Output Components: xyzs
# Trunk Encoding Hidden Dimension: 128
# Branch Hidden Dimension: 128
# Trunk Hidden Dimension: 128
# ...

# %%
# !python main.py --phase shape -N_p 5000 -i 10000 -lr 1e-4 \
  --pretrained_path ../experiments/Changed2Phase_field_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/model_final.pth
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
#
#
# Model Parameters:
# Device: cuda
# Phase: shape
# Run Number: 0
# Folder Name: Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random
# Iterations: 10000
# Batch Size: 16
# Learning Rate: 0.0001
# Number of Samples: 3000
# Data Split Method: random
# Branch Condition Input Components: mlc
# Trunk Input Components: xyzd
# Output Components: xyzs
# Trunk Encoding Hidden Dimension: 128
# Branch Hidden Dimension: 128
# Trunk Hidden Dimension: 128
# ...

# %%
# !python train_nf.py \
  --experiment_dir ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random \
  --sampled_npz ../data/sampled/Rpt0_N5000.npz \
  --split_npz ../data/npy/combined_3000_split_random_train_valid.npz \
  --device cuda:0 \
  --latent_dim 128 \
  --num_flows 4 \
  --epochs 1000
# Out:
# Encoding latents: 100%|████████████████████████| 38/38 [00:00<00:00, 126.18it/s]
# [latent] absmax=9.913490  mean=2.618870  std=1.744305
# Saved latent normalization stats to: ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/nf_latent_norm.pth
# [NF] epoch 1/1000  nll=180.910069  skipped_batches=0
# [NF] epoch 2/1000  nll=177.428317  skipped_batches=0
# [NF] epoch 3/1000  nll=167.539375  skipped_batches=0
# [NF] epoch 4/1000  nll=159.306100  skipped_batches=0
# [NF] epoch 5/1000  nll=153.428963  skipped_batches=0
# [NF] epoch 6/1000  nll=148.176330  skipped_batches=0
# [NF] epoch 7/1000  nll=144.020896  skipped_batches=0
# [NF] epoch 8/1000  nll=140.641357  skipped_batches=0
# [NF] epoch 9/1000  nll=137.148844  skipped_batches=0
# [NF] epoch 10/1000  nll=133.598747  skipped_batches=0
# [NF] epoch 11/1000  nll=129.642322  skipped_batches=0
# [NF] epoch 12/1000  nll=125.698701  skipped_batches=0
# ...

# %%
import numpy as np
split = np.load("/workspace/Point-DeepONet/data/npy/combined_3000_split_random_train_valid.npz")
print(split["train"][:20])
# Out:
# ['hor_238_489' 'ver_25_217' 'ver_20_575' 'ver_19_519' 'hor_565_79'
#  'ver_371_125' 'hor_422_291' 'ver_625_434' 'dia_479_122' 'dia_375_291'
#  'ver_438_454' 'dia_10_30' 'ver_235_389' 'ver_449_114' 'ver_28_492'
#  'ver_289_30' 'hor_270_319' 'dia_321_576' 'dia_291_186' 'ver_182_417']

# %%
# %matplotlib inline
# !python generate_and_visualize.py \
  --experiment_dir ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random \
  --data_root /workspace/Point-DeepONet/data \
  --case_key hor_422_291 \
  --num_samples 10 \
  --viz_num 10 \
  --viz_component 3 \
  --grid_n 128 \
  --grid_extent 1.5 \
  --out_dir ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/gen_outputs
# Out:
# ### RUNNING FILE: /workspace/Point-DeepONet/7.DesignGenPointDeepONet  copy/generate_and_visualize.py
# [OK] sample 0: saved ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/gen_outputs/hor_422_291_sample_000_grid.vtk and ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/gen_outputs/hor_422_291_sample_000_surface.vtk | sdf_min=-1.1234, sdf_max=2.6936
# [OK] sample 1: saved ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/gen_outputs/hor_422_291_sample_001_grid.vtk and ../experiments/Changed2Phase_shape_RUN0_D3000_N5000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/gen_outputs/hor_422_291_sample_001_surface.vtk | sdf_min=-0.8407, sdf_max=2.7526
# ...

# %%
import pyvista as pv

pv.start_xvfb()                 # (리눅스/헤드리스에서) 가상 디스플레이 시작

mesh = pv.read("../experiments/Changed_RUN0_D3000_N1000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/overall_vtks/dia_8_21.vtk")

print(mesh.point_data.keys())
print(mesh.cell_data.keys())


p = pv.Plotter(off_screen=True)
p.add_mesh(mesh, smooth_shading=True)


p.camera_position = "iso"
p.show(screenshot="./render.png")  # 창은 안 뜨고 render.png로 저장
print("saved: render.png")
# Out:
# /tmp/ipykernel_36769/1645400553.py:3: PyVistaDeprecationWarning: This function is deprecated and will be removed in future version of PyVista. Use vtk with osmesa instead.
#   pv.start_xvfb()                 # (리눅스/헤드리스에서) 가상 디스플레이 시작
# ['gt_ux', 'gt_uy', 'gt_uz', 'gt_vm', 'pred_ux', 'pred_uy', 'pred_uz', 'pred_vm']
# []
# 2026-03-04 17:18:53.550 (   3.426s) [    73CA6CFB9000]    vtkX11Functions.cxx:194   WARN| Failed to load Xcursor library
# 2026-03-04 17:18:53.688 (   3.565s) [    73CA6CFB9000]    vtkX11Functions.cxx:194   WARN| Failed to load Xcursor library
# Widget(value='<iframe src="http://localhost:46359/index.html?ui=P_0x73c9a87fa410_0&reconnect=auto" class="pyvi…
# saved: render.png
