# %%
# !python main.py \
    --gpu 0 \
    --RUN 0 \
    --branch_condition_input_components mlc \
    --trunk_input_components xyzd \
    --output_components xyzs \
    --N_pt 1000 \
    --N_iterations 10000 \
    --batch_size 16 \
    --learning_rate 0.001 \
    --dir_base_load_data ../data/sampled \
    --N_samples 3000 \
    --split_method random \
    --base_dir ../experiments \
    --branch_hidden_dim 128 \
    --trunk_hidden_dim 128 \
    --trunk_encoding_hidden_dim 128 \
    --fc_hidden_dim 128 \
    --lambda_nf 0.001
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
#
#
# Model Parameters:
# Device: cuda
# Run Number: 0
# Folder Name: DesignGenPointDeepONet_RUN0_D3000_N1000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random
# Iterations: 10000
# Batch Size: 16
# Learning Rate: 0.001
# Number of Samples: 3000
# Data Split Method: random
# Branch Condition Input Components: mlc
# Trunk Input Components: xyzd
# Output Components: xyzs
# Trunk Encoding Hidden Dimension: 128
# Branch Hidden Dimension: 128
# Trunk Hidden Dimension: 128
# Fully Connected Hidden Dimension: 128
# NF flow: RealNVP, num_flows=4, hidden=64, act=Tanh
# lambda_nf=0.001
#
#
# branch_condition_input_train.shape = (2400, 5)
# branch_pointnet_input_train.shape = (2400, 1000, 3)
# branch_condition_input_test.shape = (600, 5)
# branch_pointnet_input_test.shape = (600, 1000, 3)
# trunk_input_train.shape = (2400, 1000, 4)
# trunk_input_test.shape = (600, 1000, 4)
# s_train.shape = (2400, 1000, 4)
# s_test.shape = (600, 1000, 4)
# y_train(with sdf).shape = (2400, 1000, 5)
# y_test(with sdf).shape = (600, 1000, 5)
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Compiling model...
# 'compile' took 0.000393 s
#
#
# Model Structure:
# <deepxde.model.Model object at 0x71fa5449c390>
# Number of Trainable Parameters: 772229
#
# y_train.shape = (2400, 1000, 5)
# y_test.shape = (600, 1000, 5)
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 0         [5.58e-01]    [5.48e-01]    [5.53e-02, 1.36e-02, 1.95e-01, 6.96e+01, -1.80e+03, -1.06e+04, -2.29e+04, -4.70e+04]
# 100       [2.62e-02]    [3.17e-02]    [2.06e-02, 5.69e-03, 2.90e-02, 2.00e+01, 7.76e-01, 6.04e-01, 7.51e-01, 2.24e-01]
# 200       [2.75e-02]    [2.74e-02]    [1.80e-02, 5.27e-03, 2.48e-02, 1.88e+01, 8.53e-01, 5.74e-01, 8.72e-01, 4.39e-01]
# 300       [2.49e-02]    [2.63e-02]    [1.56e-02, 5.23e-03, 2.64e-02, 1.72e+01, 8.90e-01, 6.54e-01, 9.00e-01, 4.37e-01]
# 400       [2.28e-02]    [2.34e-02]    [1.41e-02, 4.37e-03, 2.11e-02, 1.57e+01, 8.57e-01, 6.55e-01, 8.42e-01, 5.20e-01]
# [loss] step=500 field=1.6567e-02 sdf=9.5811e-03 eik=6.6674e-01(w=0) nf=7.0776e+02(w=0) total=2.6148e-02
# 500       [1.99e-02]    [2.30e-02]    [1.48e-02, 4.41e-03, 2.16e-02, 1.59e+01, 8.58e-01, 6.91e-01, 8.48e-01, 6.19e-01]
# 600       [1.83e-02]    [2.09e-02]    [1.41e-02, 4.39e-03, 1.98e-02, 1.50e+01, 9.19e-01, 7.65e-01, 9.28e-01, 6.68e-01]
# 10000     [-2.26e-01]   [-2.10e-01]   [7.76e-03, 3.04e-03, 1.18e-02, 1.15e+01, 9.66e-01, 8.71e-01, 9.62e-01, 8.19e-01]
#
# Best model at step 9900:
#   train loss: -2.34e-01
#   test loss: -2.24e-01
#   test metric: [7.38e-03, 2.90e-03, 1.08e-02, 1.11e+01, 9.67e-01, 8.80e-01, 9.66e-01, 8.21e-01]
#
# Epoch 10000: saving model to ../experiments/DesignGenPointDeepONet_RUN0_D3000_N1000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/model_checkpoint.pth-10000.pt ...
#
# 'train' took 2362.833151 s
#
# subset Metrics for dia ux: MAE=0.0046, RMSE=0.0068, R²=0.8171
# subset Metrics for dia uy: MAE=0.0028, RMSE=0.0045, R²=0.9045
# subset Metrics for dia uz: MAE=0.0076, RMSE=0.0113, R²=0.9515
# subset Metrics for dia vm: MAE=9.3696, RMSE=14.2316, R²=0.7940
# subset Metrics for ver ux: MAE=0.0109, RMSE=0.0202, R²=0.9401
# subset Metrics for ver uy: MAE=0.0042, RMSE=0.0073, R²=0.8860
# subset Metrics for ver uz: MAE=0.0190, RMSE=0.0366, R²=0.9424
# subset Metrics for ver vm: MAE=14.2540, RMSE=21.7046, R²=0.8127
# subset Metrics for hor ux: MAE=0.0086, RMSE=0.0132, R²=0.9730
# subset Metrics for hor uy: MAE=0.0024, RMSE=0.0035, R²=0.8041
# subset Metrics for hor uz: MAE=0.0103, RMSE=0.0160, R²=0.9653
# subset Metrics for hor vm: MAE=11.3613, RMSE=16.9612, R²=0.8619
# SDF Overall: MAE=0.823639, RMSE=1.240524, R²=0.5944
# Processing Test Cases: 100%|██████████████████| 600/600 [06:10<00:00,  1.62it/s]
# Saved metrics for direction 'hor' to '../experiments/DesignGenPointDeepONet_RUN0_D3000_N1000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/overall_metrics_each/hor_metrics.npz'
# Saved metrics for direction 'dia' to '../experiments/DesignGenPointDeepONet_RUN0_D3000_N1000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/overall_metrics_each/dia_metrics.npz'
# Saved metrics for direction 'ver' to '../experiments/DesignGenPointDeepONet_RUN0_D3000_N1000_branchinput_mlc_trunkinput_xyzd_output_xyzs_split_random/overall_metrics_each/ver_metrics.npz'
# Overall Metrics for hor ux: MAE=0.0083, RMSE=0.0107, R²=0.9662
# Overall Metrics for hor uy: MAE=0.0023, RMSE=0.0030, R²=0.7934
# Overall Metrics for hor uz: MAE=0.0099, RMSE=0.0127, R²=0.9565
# Overall Metrics for hor vm: MAE=11.0326, RMSE=15.2351, R²=0.8441
# Overall Metrics for dia ux: MAE=0.0044, RMSE=0.0058, R²=0.7529
# Overall Metrics for dia uy: MAE=0.0026, RMSE=0.0037, R²=0.9055
# Overall Metrics for dia uz: MAE=0.0073, RMSE=0.0093, R²=0.9444
# Overall Metrics for dia vm: MAE=9.2229, RMSE=13.0908, R²=0.7918
# Overall Metrics for ver ux: MAE=0.0103, RMSE=0.0138, R²=0.9495
# Overall Metrics for ver uy: MAE=0.0041, RMSE=0.0056, R²=0.9079
# Overall Metrics for ver uz: MAE=0.0188, RMSE=0.0242, R²=0.9541
# Overall Metrics for ver vm: MAE=13.9261, RMSE=19.4844, R²=0.7936
