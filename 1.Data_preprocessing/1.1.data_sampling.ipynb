# %% [markdown]
# ### 1.1.1 Parallel Data Resampling and Randomness Verification
#
# This notebook demonstrates how to perform data resampling on large datasets
# using parallel processing with Python's `multiprocessing` library. The workflow includes:
#
# - **Data Resampling**: Generates multiple resampled datasets based on different parameters.
# - **Data Saving**: Efficiently saves the resampled data in compressed `.npz` files.
# - **Randomness Verification**: Ensures the randomness of the sampling process by computing and comparing MD5 hashes of the output files.
#
# By leveraging parallel processing, the resampling process is optimized for performance, making it suitable for handling large-scale data efficiently.

# %%
import numpy as np
import os
from tqdm import tqdm
import pandas as pd
from multiprocessing import Pool
import hashlib

def resample_data(args):
    """
    Resamples and saves data based on the given arguments.

    Parameters:
    - args: A tuple of arguments (rpt, N_resample, matching_keys, xyzdml_data, targets_data, N_case)
    """
    rpt, N_resample, matching_keys, xyzdml_data, targets_data, N_case = args
    input_data = np.zeros([N_case, N_resample, 9])  # input_data has 9 columns
    output_data = np.zeros([N_case, N_resample, 4])  # output_data has 4 columns
    names = []

    # Set a unique seed for each rpt (e.g., based on rpt number)
    seed = 42 + rpt  # Generate a unique seed by adding rpt to the base seed
    np.random.seed(seed)

    for k, name in enumerate(matching_keys):
        print(f"Rpt{rpt} - Processing {name} with index {k}")
        names.append(name)
        my_xyzdml = xyzdml_data[name]
        my_targets = targets_data[name]

        npt = len(my_xyzdml)
        print(f"Rpt{rpt} - npt: {npt}, N_resample: {N_resample}")

        # Generate sampling indices
        if npt <= N_resample:
            index = np.random.choice(npt, N_resample, replace=True)
        else:
            index = np.random.choice(npt, N_resample, replace=False)

        input_data[k, :, :] = my_xyzdml[index, :].copy()
        output_data[k, :, :] = my_targets[index, :].copy()

    names = np.array(names)
    np.savez_compressed(f'../data/sampled/Rpt{rpt}_N{N_resample}.npz', a=input_data, b=output_data, c=names)

def compute_hash(data):
    """
    Computes the MD5 hash of the given data.

    Parameters:
    - data: The data to hash (numpy array)

    Returns:
    - Hash string
    """
    return hashlib.md5(data.tobytes()).hexdigest()

def check_sampling_randomness(base_sampled='../data/sampled/', rpt_values=[0,1,2], N_resample_list=[500, 1000, 2000, 5000, 10000]):
    """
    Checks whether the generated files are created differently for each rpt and N_resample.

    Parameters:
    - base_sampled: Base directory where sampled data is stored
    - rpt_values: List of rpt values to check
    - N_resample_list: List of N_resample values to check
    """
    hashes = {}

    for rpt in rpt_values:
        for N_resample in N_resample_list:
            filepath = os.path.join(base_sampled, f'Rpt{rpt}_N{N_resample}.npz')
            if not os.path.exists(filepath):
                print(f"File does not exist: {filepath}")
                continue
            data = np.load(filepath)
            output_data = data['b']
            data_hash = compute_hash(output_data)
            hashes[(rpt, N_resample)] = data_hash
            print(f"Hash computed - Rpt{rpt}, N_resample={N_resample}: {data_hash}")

    # Compare hashes for each rpt and N_resample
    print("\nStarting sampling results comparison:")
    for N_resample in N_resample_list:
        hashes_per_N = [hashes.get((rpt, N_resample)) for rpt in rpt_values]
        unique_hashes = set(hashes_per_N)
        if len(unique_hashes) == len(rpt_values):
            print(f"N_resample={N_resample}: Sampling was done differently for all rpt values.")
        else:
            print(f"N_resample={N_resample}: Sampling was identical for some rpt values.")
    
    print("Sampling randomness verification completed.")

def main(cpu_count=4):
    """
    Main function that loads data, performs resampling, and validates randomness.

    Parameters:
    - cpu_count: Number of CPU cores to use
    """
    base_npy = '../data/npy/'
    base_sampled = '../data/sampled/'

    filename_xyzdmlc = 'xyzdmlc.npz'
    filename_targets = 'targets.npz'

    os.makedirs(base_sampled, exist_ok=True)

    # Load data
    xyzdml = np.load(os.path.join(base_npy, filename_xyzdmlc))
    targets = np.load(os.path.join(base_npy, filename_targets))

    # Get keys from targets and xyzdml
    xyzdml_keys = set(xyzdml.keys())
    targets_keys = set(targets.keys())

    print(f"Number of xyzdml keys: {len(xyzdml_keys)}")
    print(f"Number of targets keys: {len(targets_keys)}")

    # Find matching keys
    matching_keys = list(targets_keys.intersection(xyzdml_keys))

    # Print results
    print(f"Number of matching keys: {len(matching_keys)}")

    N_case = len(matching_keys)

    # Pre-load data into memory
    targets_data = {name: targets[name] for name in targets.files if name in matching_keys}
    xyzdml_data = {name: xyzdml[name] for name in xyzdml.files if name in matching_keys}

    
    print("Starting creating tasks")
    # Create task list
    tasks = [(rpt, N_resample, matching_keys, xyzdml_data, targets_data, N_case)
            #  for rpt in range(3) # Modify repeat number 
             for rpt in range(1) # Modify repeat number 
             for N_resample in [1000]]#[500, 1000, 2000, 5000, 10000]]  # Modify N_resample list

    # Display progress
    print("Starting resampling process...")
    #with Pool(processes=cpu_count) as pool:  # Added cpu_count argument to Pool
    #    for _ in tqdm(pool.imap_unordered(resample_data, tasks), total=len(tasks)):
    #        pass  # Display progress with tqdm
    for task in tqdm(tasks):
        resample_data(task)

    # Verify sampling randomness
    # check_sampling_randomness(base_sampled=base_sampled, rpt_values=[0,1,2], N_resample_list=[500, 1000, 2000, 5000, 10000])
    #check_sampling_randomness(base_sampled=base_sampled, rpt_values=[0], N_resample_list=[500, 1000, 2000, 5000, 10000])

if __name__ == '__main__':
    main(cpu_count=16)
# Out:
# Number of xyzdml keys: 6315
# Number of targets keys: 6315
# Number of matching keys: 6315
# Starting creating tasks
# Starting resampling process...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Rpt0 - Processing hor_80_329 with index 0
# Rpt0 - npt: 178490, N_resample: 1000
# Rpt0 - Processing hor_377_486 with index 1
# Rpt0 - npt: 179532, N_resample: 1000
# Rpt0 - Processing hor_424_245 with index 2
# Rpt0 - npt: 233792, N_resample: 1000
# Rpt0 - Processing hor_394_214 with index 3
# Rpt0 - npt: 243899, N_resample: 1000
# Rpt0 - Processing ver_510_86 with index 4
# Rpt0 - npt: 284934, N_resample: 1000
# Rpt0 - Processing dia_200_506 with index 5
# Rpt0 - npt: 159739, N_resample: 1000
# Rpt0 - Processing dia_147_418 with index 6
# Rpt0 - npt: 226072, N_resample: 1000
# Rpt0 - Processing ver_192_61 with index 7
# Rpt0 - npt: 233564, N_resample: 1000
# Rpt0 - Processing dia_285_80 with index 8
# Rpt0 - npt: 162874, N_resample: 1000
# Rpt0 - Processing dia_371_208 with index 9
# Rpt0 - npt: 230450, N_resample: 1000
# Rpt0 - Processing dia_91_625 with index 10
# Rpt0 - npt: 158429, N_resample: 1000
# Rpt0 - Processing hor_21_58 with index 11
# Rpt0 - npt: 196028, N_resample: 1000
# Rpt0 - Processing dia_214_320 with index 12
# Rpt0 - npt: 228319, N_resample: 1000
# Rpt0 - Processing dia_378_198 with index 13
# Rpt0 - npt: 272418, N_resample: 1000
# Rpt0 - Processing dia_432_564 with index 14
# Rpt0 - npt: 261797, N_resample: 1000
# Rpt0 - Processing dia_484_323 with index 15
# Rpt0 - npt: 187581, N_resample: 1000
# Rpt0 - Processing dia_221_495 with index 16
# Rpt0 - npt: 202594, N_resample: 1000
# Rpt0 - Processing hor_202_275 with index 17
# Rpt0 - npt: 166132, N_resample: 1000
# Rpt0 - Processing dia_268_323 with index 18
# Rpt0 - npt: 170111, N_resample: 1000
# Rpt0 - Processing dia_434_523 with index 19
# Rpt0 - npt: 197715, N_resample: 1000
# Rpt0 - Processing dia_241_489 with index 20
# Rpt0 - npt: 195161, N_resample: 1000
# Rpt0 - Processing hor_322_590 with index 21
# Rpt0 - npt: 149408, N_resample: 1000
# Rpt0 - Processing ver_296_605 with index 22
# Rpt0 - npt: 166436, N_resample: 1000
# Rpt0 - Processing dia_507_191 with index 23
# Rpt0 - npt: 239852, N_resample: 1000
# Rpt0 - Processing hor_79_411 with index 24
# Rpt0 - npt: 241430, N_resample: 1000
# Rpt0 - Processing hor_153_513 with index 25
# Rpt0 - npt: 191197, N_resample: 1000
# Rpt0 - Processing ver_537_290 with index 26
# Rpt0 - npt: 212425, N_resample: 1000
# Rpt0 - Processing ver_306_417 with index 27
# Rpt0 - npt: 203042, N_resample: 1000
# Rpt0 - Processing dia_456_485 with index 28
# Rpt0 - npt: 202209, N_resample: 1000
# Rpt0 - Processing ver_208_102 with index 29
# Rpt0 - npt: 225022, N_resample: 1000
# Rpt0 - Processing hor_615_102 with index 30
# Rpt0 - npt: 222145, N_resample: 1000
# Rpt0 - Processing ver_538_125 with index 31
# Rpt0 - npt: 194544, N_resample: 1000
# Rpt0 - Processing hor_191_449 with index 32
# Rpt0 - npt: 337472, N_resample: 1000
# Rpt0 - Processing dia_630_284 with index 33
# Rpt0 - npt: 226800, N_resample: 1000
# Rpt0 - Processing ver_351_255 with index 34
# Rpt0 - npt: 207785, N_resample: 1000
# Rpt0 - Processing ver_329_170 with index 35
# Rpt0 - npt: 234756, N_resample: 1000
# Rpt0 - Processing ver_361_125 with index 36
# Rpt0 - npt: 159269, N_resample: 1000
# Rpt0 - Processing hor_331_91 with index 37
# Rpt0 - npt: 214509, N_resample: 1000
# Rpt0 - Processing hor_183_538 with index 38
# Rpt0 - npt: 234297, N_resample: 1000
# Rpt0 - Processing hor_536_213 with index 39
# Rpt0 - npt: 203786, N_resample: 1000
# Rpt0 - Processing hor_484_454 with index 40
# Rpt0 - npt: 183363, N_resample: 1000
# Rpt0 - Processing dia_513_107 with index 41
# Rpt0 - npt: 196969, N_resample: 1000
# Rpt0 - Processing hor_131_187 with index 42
# Rpt0 - npt: 221718, N_resample: 1000
# Rpt0 - Processing ver_448_465 with index 43
# Rpt0 - npt: 162788, N_resample: 1000
# Rpt0 - Processing hor_187_489 with index 44
# Rpt0 - npt: 185532, N_resample: 1000
# Rpt0 - Processing dia_257_199 with index 45
# Rpt0 - npt: 203985, N_resample: 1000
# Rpt0 - Processing hor_546_549 with index 46
# Rpt0 - npt: 230693, N_resample: 1000
# Rpt0 - Processing ver_209_476 with index 47
# Rpt0 - npt: 326727, N_resample: 1000
# Rpt0 - Processing ver_371_208 with index 48
# Rpt0 - npt: 230450, N_resample: 1000
# Rpt0 - Processing hor_403_517 with index 49
# Rpt0 - npt: 263865, N_resample: 1000
# Rpt0 - Processing dia_324_249 with index 50
# Rpt0 - npt: 181764, N_resample: 1000
# Rpt0 - Processing ver_590_249 with index 51
# Rpt0 - npt: 163838, N_resample: 1000
# Rpt0 - Processing dia_125_625 with index 52
# Rpt0 - npt: 151438, N_resample: 1000
# Rpt0 - Processing dia_506_199 with index 53
# Rpt0 - npt: 169706, N_resample: 1000
# Rpt0 - Processing ver_519_418 with index 54
# Rpt0 - npt: 241254, N_resample: 1000
# Rpt0 - Processing ver_554_575 with index 55
# Rpt0 - npt: 252538, N_resample: 1000
# Rpt0 - Processing hor_415_211 with index 56
# Rpt0 - npt: 213617, N_resample: 1000
# Rpt0 - Processing ver_61_125 with index 57
# Rpt0 - npt: 186992, N_resample: 1000
# Rpt0 - Processing ver_572_87 with index 58
# Rpt0 - npt: 216454, N_resample: 1000
# Rpt0 - Processing hor_479_142 with index 59
# Rpt0 - npt: 199957, N_resample: 1000
# Rpt0 - Processing dia_489_181 with index 60
# Rpt0 - npt: 240632, N_resample: 1000
# Rpt0 - Processing hor_535_27 with index 61
# Rpt0 - npt: 246156, N_resample: 1000
# Rpt0 - Processing dia_394_58 with index 62
# Rpt0 - npt: 249479, N_resample: 1000
# Rpt0 - Processing dia_217_202 with index 63
# Rpt0 - npt: 194020, N_resample: 1000
# Rpt0 - Processing ver_282_20 with index 64
# Rpt0 - npt: 208820, N_resample: 1000
# Rpt0 - Processing dia_113_86 with index 65
# Rpt0 - npt: 249986, N_resample: 1000
# Rpt0 - Processing ver_182_122 with index 66
# Rpt0 - npt: 220673, N_resample: 1000
# Rpt0 - Processing hor_417_375 with index 67
# Rpt0 - npt: 257653, N_resample: 1000
# Rpt0 - Processing dia_289_173 with index 68
# Rpt0 - npt: 218586, N_resample: 1000
# Rpt0 - Processing ver_388_492 with index 69
# Rpt0 - npt: 226150, N_resample: 1000
# Rpt0 - Processing ver_267_519 with index 70
# Rpt0 - npt: 222458, N_resample: 1000
# Rpt0 - Processing dia_221_233 with index 71
# Rpt0 - npt: 235396, N_resample: 1000
# Rpt0 - Processing hor_238_293 with index 72
# Rpt0 - npt: 207261, N_resample: 1000
# Rpt0 - Processing hor_377_72 with index 73
# Rpt0 - npt: 237781, N_resample: 1000
# Rpt0 - Processing hor_440_345 with index 74
# Rpt0 - npt: 196281, N_resample: 1000
# Rpt0 - Processing dia_438_473 with index 75
# Rpt0 - npt: 207674, N_resample: 1000
# Rpt0 - Processing ver_506_199 with index 76
# Rpt0 - npt: 169706, N_resample: 1000
# Rpt0 - Processing hor_549_324 with index 77
# Rpt0 - npt: 233343, N_resample: 1000
# Rpt0 - Processing dia_247_35 with index 78
# Rpt0 - npt: 196174, N_resample: 1000
# Rpt0 - Processing hor_291_257 with index 79
# Rpt0 - npt: 201334, N_resample: 1000
# Rpt0 - Processing dia_554_12 with index 80
# Rpt0 - npt: 225368, N_resample: 1000
# Rpt0 - Processing dia_479_142 with index 81
# Rpt0 - npt: 199957, N_resample: 1000
# Rpt0 - Processing dia_559_14 with index 82
# Rpt0 - npt: 186611, N_resample: 1000
# Rpt0 - Processing ver_421_61 with index 83
# Rpt0 - npt: 212723, N_resample: 1000
# Rpt0 - Processing ver_472_611 with index 84
# Rpt0 - npt: 181775, N_resample: 1000
# Rpt0 - Processing hor_171_82 with index 85
# Rpt0 - npt: 259004, N_resample: 1000
# Rpt0 - Processing dia_50_586 with index 86
# Rpt0 - npt: 144557, N_resample: 1000
# Rpt0 - Processing hor_280_575 with index 87
# Rpt0 - npt: 213235, N_resample: 1000
# Rpt0 - Processing ver_131_320 with index 88
# Rpt0 - npt: 211469, N_resample: 1000
# Rpt0 - Processing ver_449_61 with index 89
# Rpt0 - npt: 303246, N_resample: 1000
# Rpt0 - Processing ver_348_211 with index 90
# Rpt0 - npt: 230215, N_resample: 1000
# Rpt0 - Processing hor_494_380 with index 91
# Rpt0 - npt: 294426, N_resample: 1000
# Rpt0 - Processing dia_194_38 with index 92
# Rpt0 - npt: 215459, N_resample: 1000
# Rpt0 - Processing hor_194_38 with index 93
# Rpt0 - npt: 215459, N_resample: 1000
# Rpt0 - Processing ver_129_295 with index 94
# Rpt0 - npt: 177839, N_resample: 1000
# Rpt0 - Processing hor_456_485 with index 95
# Rpt0 - npt: 202209, N_resample: 1000
# Rpt0 - Processing ver_280_575 with index 96
# Rpt0 - npt: 213235, N_resample: 1000
# Rpt0 - Processing ver_576_547 with index 97
# Rpt0 - npt: 170683, N_resample: 1000
# Rpt0 - Processing dia_187_411 with index 98
# Rpt0 - npt: 221366, N_resample: 1000
# Rpt0 - Processing ver_120_153 with index 99
# Rpt0 - npt: 188196, N_resample: 1000
# Rpt0 - Processing hor_15_95 with index 100
# Rpt0 - npt: 176241, N_resample: 1000
# Rpt0 - Processing ver_479_153 with index 101
# Rpt0 - npt: 149606, N_resample: 1000
# Rpt0 - Processing hor_492_535 with index 102
# Rpt0 - npt: 245627, N_resample: 1000
# Rpt0 - Processing ver_125_56 with index 103
# Rpt0 - npt: 187549, N_resample: 1000
# Rpt0 - Processing dia_488_34 with index 104
# Rpt0 - npt: 191913, N_resample: 1000
# Rpt0 - Processing dia_217_485 with index 105
# Rpt0 - npt: 250773, N_resample: 1000
# Rpt0 - Processing dia_548_280 with index 106
# Rpt0 - npt: 236475, N_resample: 1000
# Rpt0 - Processing dia_205_22 with index 107
# Rpt0 - npt: 243443, N_resample: 1000
# Rpt0 - Processing ver_291_474 with index 108
# Rpt0 - npt: 265704, N_resample: 1000
# Rpt0 - Processing ver_291_257 with index 109
# Rpt0 - npt: 201334, N_resample: 1000
# Rpt0 - Processing dia_55_80 with index 110
# Rpt0 - npt: 147945, N_resample: 1000
# Rpt0 - Processing hor_422_537 with index 111
# Rpt0 - npt: 226270, N_resample: 1000
# Rpt0 - Processing ver_270_173 with index 112
# Rpt0 - npt: 194696, N_resample: 1000
# Rpt0 - Processing ver_95_114 with index 113
# Rpt0 - npt: 186974, N_resample: 1000
# Rpt0 - Processing dia_289_497 with index 114
# Rpt0 - npt: 186420, N_resample: 1000
# Rpt0 - Processing dia_475_209 with index 115
# Rpt0 - npt: 323449, N_resample: 1000
# Rpt0 - Processing dia_570_142 with index 116
# Rpt0 - npt: 261165, N_resample: 1000
# Rpt0 - Processing dia_295_319 with index 117
# Rpt0 - npt: 200443, N_resample: 1000
# Rpt0 - Processing dia_486_380 with index 118
# Rpt0 - npt: 223547, N_resample: 1000
# Rpt0 - Processing ver_153_576 with index 119
# Rpt0 - npt: 160825, N_resample: 1000
# Rpt0 - Processing dia_61_587 with index 120
# Rpt0 - npt: 215235, N_resample: 1000
# Rpt0 - Processing hor_95_187 with index 121
# Rpt0 - npt: 188542, N_resample: 1000
# Rpt0 - Processing dia_125_58 with index 122
# Rpt0 - npt: 198404, N_resample: 1000
# Rpt0 - Processing ver_202_241 with index 123
# Rpt0 - npt: 171937, N_resample: 1000
# Rpt0 - Processing hor_319_25 with index 124
# Rpt0 - npt: 171133, N_resample: 1000
# Rpt0 - Processing dia_6_560 with index 125
# Rpt0 - npt: 212445, N_resample: 1000
# Rpt0 - Processing ver_55_320 with index 126
# Rpt0 - npt: 178257, N_resample: 1000
# Rpt0 - Processing dia_454_22 with index 127
# Rpt0 - npt: 265184, N_resample: 1000
# Rpt0 - Processing hor_91_187 with index 128
# Rpt0 - npt: 169946, N_resample: 1000
# Rpt0 - Processing dia_439_331 with index 129
# Rpt0 - npt: 254324, N_resample: 1000
# Rpt0 - Processing ver_499_206 with index 130
# Rpt0 - npt: 208493, N_resample: 1000
# Rpt0 - Processing hor_267_80 with index 131
# Rpt0 - npt: 172465, N_resample: 1000
# Rpt0 - Processing dia_125_25 with index 132
# Rpt0 - npt: 134715, N_resample: 1000
# Rpt0 - Processing hor_527_440 with index 133
# Rpt0 - npt: 244253, N_resample: 1000
# Rpt0 - Processing hor_285_80 with index 134
# Rpt0 - npt: 162874, N_resample: 1000
# Rpt0 - Processing dia_492_506 with index 135
# Rpt0 - npt: 181045, N_resample: 1000
# Rpt0 - Processing ver_384_12 with index 136
# Rpt0 - npt: 303885, N_resample: 1000
# Rpt0 - Processing hor_213_434 with index 137
# Rpt0 - npt: 311695, N_resample: 1000
# Rpt0 - Processing dia_123_389 with index 138
# Rpt0 - npt: 224494, N_resample: 1000
# Rpt0 - Processing hor_416_282 with index 139
# Rpt0 - npt: 302979, N_resample: 1000
# Rpt0 - Processing dia_319_432 with index 140
# Rpt0 - npt: 325308, N_resample: 1000
# Rpt0 - Processing dia_499_21 with index 141
# Rpt0 - npt: 143132, N_resample: 1000
# Rpt0 - Processing dia_576_511 with index 142
# Rpt0 - npt: 143312, N_resample: 1000
# Rpt0 - Processing ver_22_233 with index 143
# Rpt0 - npt: 237553, N_resample: 1000
# Rpt0 - Processing hor_506_194 with index 144
# Rpt0 - npt: 199588, N_resample: 1000
# Rpt0 - Processing ver_321_21 with index 145
# Rpt0 - npt: 163681, N_resample: 1000
# Rpt0 - Processing hor_320_424 with index 146
# Rpt0 - npt: 233726, N_resample: 1000
# Rpt0 - Processing dia_440_345 with index 147
# Rpt0 - npt: 196281, N_resample: 1000
# Rpt0 - Processing dia_377_486 with index 148
# Rpt0 - npt: 179532, N_resample: 1000
# Rpt0 - Processing hor_570_486 with index 149
# Rpt0 - npt: 176686, N_resample: 1000
# Rpt0 - Processing ver_406_472 with index 150
# Rpt0 - npt: 169225, N_resample: 1000
# Rpt0 - Processing ver_87_214 with index 151
# Rpt0 - npt: 259912, N_resample: 1000
# Rpt0 - Processing dia_473_256 with index 152
# Rpt0 - npt: 164127, N_resample: 1000
# Rpt0 - Processing hor_428_507 with index 153
# Rpt0 - npt: 282844, N_resample: 1000
# Rpt0 - Processing hor_289_58 with index 154
# Rpt0 - npt: 221946, N_resample: 1000
# Rpt0 - Processing hor_208_447 with index 155
# Rpt0 - npt: 197036, N_resample: 1000
# Rpt0 - Processing dia_245_91 with index 156
# Rpt0 - npt: 188195, N_resample: 1000
# Rpt0 - Processing ver_348_199 with index 157
# Rpt0 - npt: 210616, N_resample: 1000
# Rpt0 - Processing ver_256_295 with index 158
# Rpt0 - npt: 175698, N_resample: 1000
# Rpt0 - Processing hor_150_572 with index 159
# Rpt0 - npt: 290242, N_resample: 1000
# Rpt0 - Processing dia_537_171 with index 160
# Rpt0 - npt: 258868, N_resample: 1000
# Rpt0 - Processing ver_91_625 with index 161
# Rpt0 - npt: 158429, N_resample: 1000
# Rpt0 - Processing hor_569_466 with index 162
# Rpt0 - npt: 178047, N_resample: 1000
# Rpt0 - Processing hor_474_80 with index 163
# Rpt0 - npt: 265473, N_resample: 1000
# Rpt0 - Processing hor_492_139 with index 164
# Rpt0 - npt: 221581, N_resample: 1000
# Rpt0 - Processing ver_53_256 with index 165
# Rpt0 - npt: 217146, N_resample: 1000
# Rpt0 - Processing ver_122_14 with index 166
# Rpt0 - npt: 187902, N_resample: 1000
# Rpt0 - Processing hor_433_302 with index 167
# Rpt0 - npt: 206014, N_resample: 1000
# Rpt0 - Processing hor_495_289 with index 168
# Rpt0 - npt: 286149, N_resample: 1000
# Rpt0 - Processing ver_12_138 with index 169
# Rpt0 - npt: 205989, N_resample: 1000
# Rpt0 - Processing hor_50_28 with index 170
# Rpt0 - npt: 177195, N_resample: 1000
# Rpt0 - Processing hor_513_384 with index 171
# Rpt0 - npt: 240136, N_resample: 1000
# Rpt0 - Processing hor_275_400 with index 172
# Rpt0 - npt: 171917, N_resample: 1000
# Rpt0 - Processing ver_221_561 with index 173
# Rpt0 - npt: 219481, N_resample: 1000
# Rpt0 - Processing hor_195_95 with index 174
# Rpt0 - npt: 227956, N_resample: 1000
# Rpt0 - Processing ver_323_437 with index 175
# Rpt0 - npt: 186626, N_resample: 1000
# Rpt0 - Processing hor_406_86 with index 176
# Rpt0 - npt: 187075, N_resample: 1000
# Rpt0 - Processing hor_483_421 with index 177
# Rpt0 - npt: 189616, N_resample: 1000
# Rpt0 - Processing dia_533_630 with index 178
# Rpt0 - npt: 140964, N_resample: 1000
# Rpt0 - Processing dia_66_523 with index 179
# Rpt0 - npt: 183227, N_resample: 1000
# Rpt0 - Processing ver_139_519 with index 180
# Rpt0 - npt: 222724, N_resample: 1000
# Rpt0 - Processing dia_53_482 with index 181
# Rpt0 - npt: 215881, N_resample: 1000
# Rpt0 - Processing dia_378_433 with index 182
# Rpt0 - npt: 248571, N_resample: 1000
# Rpt0 - Processing dia_14_538 with index 183
# Rpt0 - npt: 207389, N_resample: 1000
# Rpt0 - Processing ver_289_342 with index 184
# Rpt0 - npt: 191432, N_resample: 1000
# Rpt0 - Processing ver_80_483 with index 185
# Rpt0 - npt: 170542, N_resample: 1000
# Rpt0 - Processing hor_499_21 with index 186
# Rpt0 - npt: 143132, N_resample: 1000
# Rpt0 - Processing ver_14_473 with index 187
# Rpt0 - npt: 175068, N_resample: 1000
# Rpt0 - Processing dia_552_270 with index 188
# Rpt0 - npt: 232884, N_resample: 1000
# Rpt0 - Processing dia_293_27 with index 189
# Rpt0 - npt: 197628, N_resample: 1000
# Rpt0 - Processing ver_411_66 with index 190
# Rpt0 - npt: 217302, N_resample: 1000
# Rpt0 - Processing ver_428_507 with index 191
# Rpt0 - npt: 282844, N_resample: 1000
# Rpt0 - Processing dia_586_533 with index 192
# Rpt0 - npt: 147100, N_resample: 1000
# Rpt0 - Processing hor_182_506 with index 193
# Rpt0 - npt: 184349, N_resample: 1000
# Rpt0 - Processing ver_324_306 with index 194
# Rpt0 - npt: 187446, N_resample: 1000
# Rpt0 - Processing ver_209_16 with index 195
# Rpt0 - npt: 202841, N_resample: 1000
# Rpt0 - Processing dia_322_560 with index 196
# Rpt0 - npt: 158834, N_resample: 1000
# Rpt0 - Processing ver_454_22 with index 197
# Rpt0 - npt: 265184, N_resample: 1000
# Rpt0 - Processing ver_625_525 with index 198
# Rpt0 - npt: 264229, N_resample: 1000
# Rpt0 - Processing dia_433_519 with index 199
# Rpt0 - npt: 213090, N_resample: 1000
# Rpt0 - Processing ver_546_323 with index 200
# Rpt0 - npt: 213598, N_resample: 1000
# Rpt0 - Processing ver_625_466 with index 201
# Rpt0 - npt: 147438, N_resample: 1000
# Rpt0 - Processing ver_460_394 with index 202
# Rpt0 - npt: 237981, N_resample: 1000
# Rpt0 - Processing ver_371_486 with index 203
# Rpt0 - npt: 170980, N_resample: 1000
# Rpt0 - Processing dia_247_50 with index 204
# Rpt0 - npt: 162864, N_resample: 1000
# Rpt0 - Processing hor_66_590 with index 205
# Rpt0 - npt: 168730, N_resample: 1000
# Rpt0 - Processing dia_536_560 with index 206
# Rpt0 - npt: 161717, N_resample: 1000
# Rpt0 - Processing dia_249_447 with index 207
# Rpt0 - npt: 168347, N_resample: 1000
# Rpt0 - Processing hor_182_247 with index 208
# Rpt0 - npt: 245631, N_resample: 1000
# Rpt0 - Processing hor_200_61 with index 209
# Rpt0 - npt: 217728, N_resample: 1000
# Rpt0 - Processing dia_465_421 with index 210
# Rpt0 - npt: 238436, N_resample: 1000
# Rpt0 - Processing hor_181_506 with index 211
# Rpt0 - npt: 199824, N_resample: 1000
# Rpt0 - Processing ver_375_291 with index 212
# Rpt0 - npt: 219634, N_resample: 1000
# Rpt0 - Processing hor_38_249 with index 213
# Rpt0 - npt: 171170, N_resample: 1000
# Rpt0 - Processing dia_255_181 with index 214
# Rpt0 - npt: 251524, N_resample: 1000
# Rpt0 - Processing dia_388_348 with index 215
# Rpt0 - npt: 184482, N_resample: 1000
# Rpt0 - Processing dia_20_320 with index 216
# Rpt0 - npt: 200810, N_resample: 1000
# Rpt0 - Processing ver_552_138 with index 217
# Rpt0 - npt: 265033, N_resample: 1000
# Rpt0 - Processing dia_554_575 with index 218
# Rpt0 - npt: 252538, N_resample: 1000
# Rpt0 - Processing hor_147_125 with index 219
# Rpt0 - npt: 159464, N_resample: 1000
# Rpt0 - Processing dia_575_630 with index 220
# Rpt0 - npt: 184640, N_resample: 1000
# Rpt0 - Processing ver_630_268 with index 221
# Rpt0 - npt: 163017, N_resample: 1000
# Rpt0 - Processing dia_633_447 with index 222
# Rpt0 - npt: 190764, N_resample: 1000
# Rpt0 - Processing ver_633_187 with index 223
# Rpt0 - npt: 199040, N_resample: 1000
# Rpt0 - Processing hor_388_268 with index 224
# Rpt0 - npt: 182327, N_resample: 1000
# Rpt0 - Processing ver_634_14 with index 225
# Rpt0 - npt: 212833, N_resample: 1000
# Rpt0 - Processing hor_590_183 with index 226
# Rpt0 - npt: 199272, N_resample: 1000
# Rpt0 - Processing hor_438_560 with index 227
# Rpt0 - npt: 228638, N_resample: 1000
# Rpt0 - Processing dia_225_576 with index 228
# Rpt0 - npt: 196606, N_resample: 1000
# Rpt0 - Processing dia_291_474 with index 229
# Rpt0 - npt: 265704, N_resample: 1000
# Rpt0 - Processing ver_285_205 with index 230
# Rpt0 - npt: 232374, N_resample: 1000
# Rpt0 - Processing dia_329_572 with index 231
# Rpt0 - npt: 201832, N_resample: 1000
# Rpt0 - Processing ver_116_30 with index 232
# Rpt0 - npt: 152853, N_resample: 1000
# Rpt0 - Processing ver_440_345 with index 233
# Rpt0 - npt: 196281, N_resample: 1000
# Rpt0 - Processing ver_633_331 with index 234
# Rpt0 - npt: 272274, N_resample: 1000
# Rpt0 - Processing ver_576_494 with index 235
# Rpt0 - npt: 160488, N_resample: 1000
# Rpt0 - Processing dia_517_441 with index 236
# Rpt0 - npt: 229178, N_resample: 1000
# Rpt0 - Processing ver_538_488 with index 237
# Rpt0 - npt: 217902, N_resample: 1000
# Rpt0 - Processing hor_123_183 with index 238
# Rpt0 - npt: 271009, N_resample: 1000
# Rpt0 - Processing dia_428_507 with index 239
# Rpt0 - npt: 282844, N_resample: 1000
# Rpt0 - Processing hor_624_234 with index 240
# Rpt0 - npt: 181109, N_resample: 1000
# Rpt0 - Processing hor_329_275 with index 241
# Rpt0 - npt: 196461, N_resample: 1000
# Rpt0 - Processing ver_140_447 with index 242
# Rpt0 - npt: 226823, N_resample: 1000
# Rpt0 - Processing dia_572_122 with index 243
# Rpt0 - npt: 187606, N_resample: 1000
# Rpt0 - Processing dia_351_255 with index 244
# Rpt0 - npt: 207785, N_resample: 1000
# Rpt0 - Processing hor_484_556 with index 245
# Rpt0 - npt: 197894, N_resample: 1000
# Rpt0 - Processing ver_19_321 with index 246
# Rpt0 - npt: 205268, N_resample: 1000
# Rpt0 - Processing hor_214_320 with index 247
# Rpt0 - npt: 228319, N_resample: 1000
# Rpt0 - Processing ver_492_538 with index 248
# Rpt0 - npt: 246998, N_resample: 1000
# Rpt0 - Processing hor_378_403 with index 249
# Rpt0 - npt: 348810, N_resample: 1000
# Rpt0 - Processing dia_55_267 with index 250
# Rpt0 - npt: 173340, N_resample: 1000
# Rpt0 - Processing hor_142_634 with index 251
# Rpt0 - npt: 222347, N_resample: 1000
# Rpt0 - Processing hor_268_390 with index 252
# Rpt0 - npt: 179395, N_resample: 1000
# Rpt0 - Processing ver_76_146 with index 253
# Rpt0 - npt: 233675, N_resample: 1000
# Rpt0 - Processing hor_486_148 with index 254
# Rpt0 - npt: 151377, N_resample: 1000
# Rpt0 - Processing hor_195_55 with index 255
# Rpt0 - npt: 207478, N_resample: 1000
# Rpt0 - Processing hor_560_377 with index 256
# Rpt0 - npt: 190027, N_resample: 1000
# Rpt0 - Processing ver_472_267 with index 257
# Rpt0 - npt: 182932, N_resample: 1000
# Rpt0 - Processing hor_321_348 with index 258
# Rpt0 - npt: 200081, N_resample: 1000
# Rpt0 - Processing ver_29_322 with index 259
# Rpt0 - npt: 164932, N_resample: 1000
# Rpt0 - Processing ver_28_474 with index 260
# Rpt0 - npt: 289560, N_resample: 1000
# Rpt0 - Processing dia_234_173 with index 261
# Rpt0 - npt: 209632, N_resample: 1000
# Rpt0 - Processing hor_28_512 with index 262
# Rpt0 - npt: 224690, N_resample: 1000
# Rpt0 - Processing hor_524_411 with index 263
# Rpt0 - npt: 198757, N_resample: 1000
# Rpt0 - Processing hor_202_58 with index 264
# Rpt0 - npt: 192799, N_resample: 1000
# Rpt0 - Processing ver_538_559 with index 265
# Rpt0 - npt: 208757, N_resample: 1000
# Rpt0 - Processing ver_257_87 with index 266
# Rpt0 - npt: 223538, N_resample: 1000
# Rpt0 - Processing dia_625_472 with index 267
# Rpt0 - npt: 180780, N_resample: 1000
# Rpt0 - Processing ver_240_564 with index 268
# Rpt0 - npt: 196332, N_resample: 1000
# Rpt0 - Processing dia_153_324 with index 269
# Rpt0 - npt: 166353, N_resample: 1000
# Rpt0 - Processing dia_10_30 with index 270
# Rpt0 - npt: 158221, N_resample: 1000
# Rpt0 - Processing hor_198_460 with index 271
# Rpt0 - npt: 201148, N_resample: 1000
# Rpt0 - Processing dia_438_119 with index 272
# Rpt0 - npt: 270303, N_resample: 1000
# Rpt0 - Processing hor_633_512 with index 273
# Rpt0 - npt: 213029, N_resample: 1000
# Rpt0 - Processing dia_424_245 with index 274
# Rpt0 - npt: 233792, N_resample: 1000
# Rpt0 - Processing dia_538_125 with index 275
# Rpt0 - npt: 194544, N_resample: 1000
# Rpt0 - Processing hor_14_139 with index 276
# Rpt0 - npt: 197086, N_resample: 1000
# Rpt0 - Processing dia_547_182 with index 277
# Rpt0 - npt: 279420, N_resample: 1000
# Rpt0 - Processing hor_422_519 with index 278
# Rpt0 - npt: 197894, N_resample: 1000
# Rpt0 - Processing hor_411_433 with index 279
# Rpt0 - npt: 251385, N_resample: 1000
# Rpt0 - Processing dia_483_421 with index 280
# Rpt0 - npt: 189616, N_resample: 1000
# Rpt0 - Processing dia_486_148 with index 281
# Rpt0 - npt: 151377, N_resample: 1000
# Rpt0 - Processing dia_438_454 with index 282
# Rpt0 - npt: 209532, N_resample: 1000
# Rpt0 - Processing dia_465_472 with index 283
# Rpt0 - npt: 211156, N_resample: 1000
# Rpt0 - Processing ver_549_220 with index 284
# Rpt0 - npt: 242990, N_resample: 1000
# Rpt0 - Processing ver_306_268 with index 285
# Rpt0 - npt: 200224, N_resample: 1000
# Rpt0 - Processing ver_241_562 with index 286
# Rpt0 - npt: 186886, N_resample: 1000
# Rpt0 - Processing dia_569_495 with index 287
# Rpt0 - npt: 235259, N_resample: 1000
# Rpt0 - Processing hor_319_432 with index 288
# Rpt0 - npt: 325308, N_resample: 1000
# Rpt0 - Processing hor_247_50 with index 289
# Rpt0 - npt: 162864, N_resample: 1000
# Rpt0 - Processing ver_576_511 with index 290
# Rpt0 - npt: 143312, N_resample: 1000
# Rpt0 - Processing dia_114_456 with index 291
# Rpt0 - npt: 190969, N_resample: 1000
# Rpt0 - Processing dia_62_590 with index 292
# Rpt0 - npt: 147908, N_resample: 1000
# Rpt0 - Processing ver_38_14 with index 293
# Rpt0 - npt: 184174, N_resample: 1000
# Rpt0 - Processing dia_91_187 with index 294
# Rpt0 - npt: 169946, N_resample: 1000
# Rpt0 - Processing ver_403_434 with index 295
# Rpt0 - npt: 275604, N_resample: 1000
# Rpt0 - Processing hor_107_342 with index 296
# Rpt0 - npt: 205599, N_resample: 1000
# Rpt0 - Processing dia_460_207 with index 297
# Rpt0 - npt: 194087, N_resample: 1000
# Rpt0 - Processing ver_9_170 with index 298
# Rpt0 - npt: 224816, N_resample: 1000
# Rpt0 - Processing dia_285_131 with index 299
# Rpt0 - npt: 221559, N_resample: 1000
# Rpt0 - Processing hor_91_630 with index 300
# Rpt0 - npt: 151256, N_resample: 1000
# Rpt0 - Processing dia_488_220 with index 301
# Rpt0 - npt: 217580, N_resample: 1000
# Rpt0 - Processing dia_610_153 with index 302
# Rpt0 - npt: 191240, N_resample: 1000
# Rpt0 - Processing dia_174_538 with index 303
# Rpt0 - npt: 223770, N_resample: 1000
# Rpt0 - Processing ver_449_472 with index 304
# Rpt0 - npt: 254102, N_resample: 1000
# Rpt0 - Processing hor_182_417 with index 305
# Rpt0 - npt: 218102, N_resample: 1000
# Rpt0 - Processing ver_240_257 with index 306
# Rpt0 - npt: 195263, N_resample: 1000
# Rpt0 - Processing dia_572_131 with index 307
# Rpt0 - npt: 189646, N_resample: 1000
# Rpt0 - Processing hor_428_235 with index 308
# Rpt0 - npt: 279583, N_resample: 1000
# Rpt0 - Processing hor_575_517 with index 309
# Rpt0 - npt: 212972, N_resample: 1000
# Rpt0 - Processing dia_371_9 with index 310
# Rpt0 - npt: 184132, N_resample: 1000
# Rpt0 - Processing hor_466_324 with index 311
# Rpt0 - npt: 181669, N_resample: 1000
# Rpt0 - Processing ver_549_324 with index 312
# Rpt0 - npt: 233343, N_resample: 1000
# Rpt0 - Processing dia_506_497 with index 313
# Rpt0 - npt: 139793, N_resample: 1000
# Rpt0 - Processing dia_15_50 with index 314
# Rpt0 - npt: 149145, N_resample: 1000
# Rpt0 - Processing hor_146_195 with index 315
# Rpt0 - npt: 248567, N_resample: 1000
# Rpt0 - Processing dia_289_342 with index 316
# Rpt0 - npt: 191432, N_resample: 1000
# Rpt0 - Processing dia_235_35 with index 317
# Rpt0 - npt: 181988, N_resample: 1000
# Rpt0 - Processing ver_562_30 with index 318
# Rpt0 - npt: 150023, N_resample: 1000
# Rpt0 - Processing ver_523_633 with index 319
# Rpt0 - npt: 176944, N_resample: 1000
# Rpt0 - Processing dia_615_182 with index 320
# Rpt0 - npt: 258256, N_resample: 1000
# Rpt0 - Processing ver_20_320 with index 321
# Rpt0 - npt: 200810, N_resample: 1000
# Rpt0 - Processing dia_25_296 with index 322
# Rpt0 - npt: 146964, N_resample: 1000
# Rpt0 - Processing hor_403_28 with index 323
# Rpt0 - npt: 298603, N_resample: 1000
# Rpt0 - Processing dia_12_524 with index 324
# Rpt0 - npt: 152987, N_resample: 1000
# Rpt0 - Processing dia_549_377 with index 325
# Rpt0 - npt: 209093, N_resample: 1000
# Rpt0 - Processing dia_384_12 with index 326
# Rpt0 - npt: 303885, N_resample: 1000
# Rpt0 - Processing hor_323_198 with index 327
# Rpt0 - npt: 170218, N_resample: 1000
# Rpt0 - Processing ver_492_535 with index 328
# Rpt0 - npt: 245627, N_resample: 1000
# Rpt0 - Processing dia_507_624 with index 329
# Rpt0 - npt: 159839, N_resample: 1000
# Rpt0 - Processing dia_240_256 with index 330
# Rpt0 - npt: 196513, N_resample: 1000
# Rpt0 - Processing hor_213_241 with index 331
# Rpt0 - npt: 281588, N_resample: 1000
# Rpt0 - Processing dia_183_536 with index 332
# Rpt0 - npt: 205533, N_resample: 1000
# Rpt0 - Processing ver_120_485 with index 333
# Rpt0 - npt: 258292, N_resample: 1000
# Rpt0 - Processing dia_267_519 with index 334
# Rpt0 - npt: 222458, N_resample: 1000
# Rpt0 - Processing hor_59_564 with index 335
# Rpt0 - npt: 173667, N_resample: 1000
# Rpt0 - Processing ver_562_569 with index 336
# Rpt0 - npt: 184645, N_resample: 1000
# Rpt0 - Processing ver_9_61 with index 337
# Rpt0 - npt: 196272, N_resample: 1000
# Rpt0 - Processing ver_76_255 with index 338
# Rpt0 - npt: 216331, N_resample: 1000
# Rpt0 - Processing dia_248_611 with index 339
# Rpt0 - npt: 188906, N_resample: 1000
# Rpt0 - Processing ver_153_289 with index 340
# Rpt0 - npt: 203086, N_resample: 1000
# Rpt0 - Processing dia_494_564 with index 341
# Rpt0 - npt: 200389, N_resample: 1000
# Rpt0 - Processing dia_205_56 with index 342
# Rpt0 - npt: 238167, N_resample: 1000
# Rpt0 - Processing dia_339_489 with index 343
# Rpt0 - npt: 151457, N_resample: 1000
# Rpt0 - Processing dia_538_107 with index 344
# Rpt0 - npt: 220623, N_resample: 1000
# Rpt0 - Processing ver_460_293 with index 345
# Rpt0 - npt: 190913, N_resample: 1000
# Rpt0 - Processing hor_270_417 with index 346
# Rpt0 - npt: 191604, N_resample: 1000
# Rpt0 - Processing hor_625_394 with index 347
# Rpt0 - npt: 224414, N_resample: 1000
# Rpt0 - Processing ver_147_418 with index 348
# Rpt0 - npt: 226072, N_resample: 1000
# Rpt0 - Processing dia_208_400 with index 349
# Rpt0 - npt: 193531, N_resample: 1000
# Rpt0 - Processing dia_15_27 with index 350
# Rpt0 - npt: 235524, N_resample: 1000
# Rpt0 - Processing hor_428_527 with index 351
# Rpt0 - npt: 366824, N_resample: 1000
# Rpt0 - Processing ver_22_527 with index 352
# Rpt0 - npt: 288382, N_resample: 1000
# Rpt0 - Processing ver_8_139 with index 353
# Rpt0 - npt: 177977, N_resample: 1000
# Rpt0 - Processing ver_395_417 with index 354
# Rpt0 - npt: 263561, N_resample: 1000
# Rpt0 - Processing hor_152_517 with index 355
# Rpt0 - npt: 232534, N_resample: 1000
# Rpt0 - Processing ver_473_519 with index 356
# Rpt0 - npt: 198546, N_resample: 1000
# Rpt0 - Processing dia_390_238 with index 357
# Rpt0 - npt: 204710, N_resample: 1000
# Rpt0 - Processing ver_417_375 with index 358
# Rpt0 - npt: 257653, N_resample: 1000
# Rpt0 - Processing hor_56_335 with index 359
# Rpt0 - npt: 290984, N_resample: 1000
# Rpt0 - Processing hor_519_58 with index 360
# Rpt0 - npt: 255520, N_resample: 1000
# Rpt0 - Processing hor_624_198 with index 361
# Rpt0 - npt: 190313, N_resample: 1000
# Rpt0 - Processing dia_316_170 with index 362
# Rpt0 - npt: 295217, N_resample: 1000
# Rpt0 - Processing hor_506_572 with index 363
# Rpt0 - npt: 150146, N_resample: 1000
# Rpt0 - Processing ver_449_559 with index 364
# Rpt0 - npt: 233694, N_resample: 1000
# Rpt0 - Processing ver_25_296 with index 365
# Rpt0 - npt: 146964, N_resample: 1000
# Rpt0 - Processing dia_173_59 with index 366
# Rpt0 - npt: 176863, N_resample: 1000
# Rpt0 - Processing dia_257_56 with index 367
# Rpt0 - npt: 196243, N_resample: 1000
# Rpt0 - Processing hor_633_447 with index 368
# Rpt0 - npt: 190764, N_resample: 1000
# Rpt0 - Processing hor_214_81 with index 369
# Rpt0 - npt: 187053, N_resample: 1000
# Rpt0 - Processing ver_348_113 with index 370
# Rpt0 - npt: 225872, N_resample: 1000
# Rpt0 - Processing hor_230_492 with index 371
# Rpt0 - npt: 233760, N_resample: 1000
# Rpt0 - Processing hor_439_140 with index 372
# Rpt0 - npt: 272816, N_resample: 1000
# Rpt0 - Processing ver_81_564 with index 373
# Rpt0 - npt: 173971, N_resample: 1000
# Rpt0 - Processing dia_547_295 with index 374
# Rpt0 - npt: 215982, N_resample: 1000
# Rpt0 - Processing dia_384_411 with index 375
# Rpt0 - npt: 240975, N_resample: 1000
# Rpt0 - Processing ver_21_25 with index 376
# Rpt0 - npt: 127970, N_resample: 1000
# Rpt0 - Processing ver_267_321 with index 377
# Rpt0 - npt: 224144, N_resample: 1000
# Rpt0 - Processing dia_513_10 with index 378
# Rpt0 - npt: 186859, N_resample: 1000
# Rpt0 - Processing hor_422_616 with index 379
# Rpt0 - npt: 222213, N_resample: 1000
# Rpt0 - Processing dia_241_562 with index 380
# Rpt0 - npt: 186886, N_resample: 1000
# Rpt0 - Processing hor_12_524 with index 381
# Rpt0 - npt: 152987, N_resample: 1000
# Rpt0 - Processing ver_240_378 with index 382
# Rpt0 - npt: 261067, N_resample: 1000
# Rpt0 - Processing dia_221_439 with index 383
# Rpt0 - npt: 220576, N_resample: 1000
# Rpt0 - Processing dia_87_329 with index 384
# Rpt0 - npt: 235748, N_resample: 1000
# Rpt0 - Processing dia_545_122 with index 385
# Rpt0 - npt: 248469, N_resample: 1000
# Rpt0 - Processing hor_284_466 with index 386
# Rpt0 - npt: 245074, N_resample: 1000
# Rpt0 - Processing dia_38_633 with index 387
# Rpt0 - npt: 209196, N_resample: 1000
# Rpt0 - Processing dia_492_140 with index 388
# Rpt0 - npt: 244648, N_resample: 1000
# Rpt0 - Processing hor_513_322 with index 389
# Rpt0 - npt: 176022, N_resample: 1000
# Rpt0 - Processing ver_202_285 with index 390
# Rpt0 - npt: 162631, N_resample: 1000
# Rpt0 - Processing ver_411_293 with index 391
# Rpt0 - npt: 229480, N_resample: 1000
# Rpt0 - Processing hor_129_187 with index 392
# Rpt0 - npt: 196529, N_resample: 1000
# Rpt0 - Processing ver_624_120 with index 393
# Rpt0 - npt: 184048, N_resample: 1000
# Rpt0 - Processing ver_551_342 with index 394
# Rpt0 - npt: 226231, N_resample: 1000
# Rpt0 - Processing ver_173_59 with index 395
# Rpt0 - npt: 176863, N_resample: 1000
# Rpt0 - Processing hor_421_319 with index 396
# Rpt0 - npt: 234841, N_resample: 1000
# Rpt0 - Processing ver_280_21 with index 397
# Rpt0 - npt: 185178, N_resample: 1000
# Rpt0 - Processing hor_267_570 with index 398
# Rpt0 - npt: 220520, N_resample: 1000
# Rpt0 - Processing dia_519_321 with index 399
# Rpt0 - npt: 205370, N_resample: 1000
# Rpt0 - Processing dia_624_87 with index 400
# Rpt0 - npt: 227032, N_resample: 1000
# Rpt0 - Processing dia_202_293 with index 401
# Rpt0 - npt: 152906, N_resample: 1000
# Rpt0 - Processing dia_200_289 with index 402
# Rpt0 - npt: 221674, N_resample: 1000
# Rpt0 - Processing dia_102_249 with index 403
# Rpt0 - npt: 211173, N_resample: 1000
# Rpt0 - Processing dia_202_107 with index 404
# Rpt0 - npt: 172314, N_resample: 1000
# Rpt0 - Processing hor_289_319 with index 405
# Rpt0 - npt: 244659, N_resample: 1000
# Rpt0 - Processing ver_296_113 with index 406
# Rpt0 - npt: 205346, N_resample: 1000
# Rpt0 - Processing ver_570_142 with index 407
# Rpt0 - npt: 261165, N_resample: 1000
# Rpt0 - Processing ver_59_320 with index 408
# Rpt0 - npt: 168138, N_resample: 1000
# Rpt0 - Processing dia_8_605 with index 409
# Rpt0 - npt: 145871, N_resample: 1000
# Rpt0 - Processing dia_91_506 with index 410
# Rpt0 - npt: 143738, N_resample: 1000
# Rpt0 - Processing hor_322_6 with index 411
# Rpt0 - npt: 184431, N_resample: 1000
# Rpt0 - Processing hor_421_235 with index 412
# Rpt0 - npt: 220755, N_resample: 1000
# Rpt0 - Processing hor_56_186 with index 413
# Rpt0 - npt: 248701, N_resample: 1000
# Rpt0 - Processing dia_125_449 with index 414
# Rpt0 - npt: 208136, N_resample: 1000
# Rpt0 - Processing hor_61_331 with index 415
# Rpt0 - npt: 235081, N_resample: 1000
# Rpt0 - Processing hor_199_548 with index 416
# Rpt0 - npt: 220244, N_resample: 1000
# Rpt0 - Processing dia_527_472 with index 417
# Rpt0 - npt: 320262, N_resample: 1000
# Rpt0 - Processing ver_56_21 with index 418
# Rpt0 - npt: 180977, N_resample: 1000
# Rpt0 - Processing hor_592_80 with index 419
# Rpt0 - npt: 221920, N_resample: 1000
# Rpt0 - Processing ver_82_209 with index 420
# Rpt0 - npt: 263186, N_resample: 1000
# Rpt0 - Processing ver_415_565 with index 421
# Rpt0 - npt: 192518, N_resample: 1000
# Rpt0 - Processing hor_289_624 with index 422
# Rpt0 - npt: 197755, N_resample: 1000
# Rpt0 - Processing hor_323_560 with index 423
# Rpt0 - npt: 159353, N_resample: 1000
# Rpt0 - Processing dia_419_380 with index 424
# Rpt0 - npt: 371515, N_resample: 1000
# Rpt0 - Processing dia_425_506 with index 425
# Rpt0 - npt: 196767, N_resample: 1000
# Rpt0 - Processing ver_422_207 with index 426
# Rpt0 - npt: 213924, N_resample: 1000
# Rpt0 - Processing hor_323_66 with index 427
# Rpt0 - npt: 175948, N_resample: 1000
# Rpt0 - Processing hor_590_21 with index 428
# Rpt0 - npt: 138769, N_resample: 1000
# Rpt0 - Processing ver_440_198 with index 429
# Rpt0 - npt: 175541, N_resample: 1000
# Rpt0 - Processing dia_518_209 with index 430
# Rpt0 - npt: 277760, N_resample: 1000
# Rpt0 - Processing hor_238_523 with index 431
# Rpt0 - npt: 182939, N_resample: 1000
# Rpt0 - Processing ver_56_440 with index 432
# Rpt0 - npt: 194980, N_resample: 1000
# Rpt0 - Processing hor_123_454 with index 433
# Rpt0 - npt: 183429, N_resample: 1000
# Rpt0 - Processing hor_342_282 with index 434
# Rpt0 - npt: 326949, N_resample: 1000
# Rpt0 - Processing ver_34_511 with index 435
# Rpt0 - npt: 170616, N_resample: 1000
# Rpt0 - Processing dia_441_205 with index 436
# Rpt0 - npt: 266351, N_resample: 1000
# Rpt0 - Processing dia_565_562 with index 437
# Rpt0 - npt: 209248, N_resample: 1000
# Rpt0 - Processing hor_211_322 with index 438
# Rpt0 - npt: 196826, N_resample: 1000
# Rpt0 - Processing hor_565_79 with index 439
# Rpt0 - npt: 325623, N_resample: 1000
# Rpt0 - Processing dia_56_255 with index 440
# Rpt0 - npt: 205268, N_resample: 1000
# Rpt0 - Processing dia_122_351 with index 441
# Rpt0 - npt: 192623, N_resample: 1000
# Rpt0 - Processing hor_427_473 with index 442
# Rpt0 - npt: 204809, N_resample: 1000
# Rpt0 - Processing dia_77_81 with index 443
# Rpt0 - npt: 180961, N_resample: 1000
# Rpt0 - Processing ver_424_533 with index 444
# Rpt0 - npt: 178909, N_resample: 1000
# Rpt0 - Processing hor_488_611 with index 445
# Rpt0 - npt: 174818, N_resample: 1000
# Rpt0 - Processing hor_384_12 with index 446
# Rpt0 - npt: 303885, N_resample: 1000
# Rpt0 - Processing ver_120_131 with index 447
# Rpt0 - npt: 247689, N_resample: 1000
# Rpt0 - Processing dia_560_199 with index 448
# Rpt0 - npt: 193593, N_resample: 1000
# Rpt0 - Processing ver_192_306 with index 449
# Rpt0 - npt: 281732, N_resample: 1000
# Rpt0 - Processing ver_456_472 with index 450
# Rpt0 - npt: 197802, N_resample: 1000
# Rpt0 - Processing hor_192_306 with index 451
# Rpt0 - npt: 281732, N_resample: 1000
# Rpt0 - Processing dia_34_295 with index 452
# Rpt0 - npt: 149635, N_resample: 1000
# Rpt0 - Processing ver_454_241 with index 453
# Rpt0 - npt: 180716, N_resample: 1000
# Rpt0 - Processing dia_8_113 with index 454
# Rpt0 - npt: 193734, N_resample: 1000
# Rpt0 - Processing dia_256_447 with index 455
# Rpt0 - npt: 169994, N_resample: 1000
# Rpt0 - Processing hor_576_560 with index 456
# Rpt0 - npt: 152964, N_resample: 1000
# Rpt0 - Processing dia_323_518 with index 457
# Rpt0 - npt: 189365, N_resample: 1000
# Rpt0 - Processing ver_233_550 with index 458
# Rpt0 - npt: 364835, N_resample: 1000
# Rpt0 - Processing ver_323_302 with index 459
# Rpt0 - npt: 175796, N_resample: 1000
# Rpt0 - Processing dia_537_513 with index 460
# Rpt0 - npt: 211863, N_resample: 1000
# Rpt0 - Processing ver_378_403 with index 461
# Rpt0 - npt: 348810, N_resample: 1000
# Rpt0 - Processing dia_107_459 with index 462
# Rpt0 - npt: 206544, N_resample: 1000
# Rpt0 - Processing ver_58_81 with index 463
# Rpt0 - npt: 186095, N_resample: 1000
# Rpt0 - Processing hor_519_351 with index 464
# Rpt0 - npt: 224713, N_resample: 1000
# Rpt0 - Processing hor_605_191 with index 465
# Rpt0 - npt: 210123, N_resample: 1000
# Rpt0 - Processing hor_415_191 with index 466
# Rpt0 - npt: 247580, N_resample: 1000
# Rpt0 - Processing hor_59_122 with index 467
# Rpt0 - npt: 153393, N_resample: 1000
# Rpt0 - Processing ver_395_537 with index 468
# Rpt0 - npt: 282577, N_resample: 1000
# Rpt0 - Processing ver_449_202 with index 469
# Rpt0 - npt: 199291, N_resample: 1000
# Rpt0 - Processing ver_322_421 with index 470
# Rpt0 - npt: 170598, N_resample: 1000
# Rpt0 - Processing hor_630_114 with index 471
# Rpt0 - npt: 162581, N_resample: 1000
# Rpt0 - Processing dia_195_440 with index 472
# Rpt0 - npt: 200903, N_resample: 1000
# Rpt0 - Processing dia_590_576 with index 473
# Rpt0 - npt: 147229, N_resample: 1000
# Rpt0 - Processing dia_293_489 with index 474
# Rpt0 - npt: 176888, N_resample: 1000
# Rpt0 - Processing dia_20_207 with index 475
# Rpt0 - npt: 224503, N_resample: 1000
# Rpt0 - Processing ver_198_257 with index 476
# Rpt0 - npt: 203135, N_resample: 1000
# Rpt0 - Processing ver_138_494 with index 477
# Rpt0 - npt: 217145, N_resample: 1000
# Rpt0 - Processing ver_66_183 with index 478
# Rpt0 - npt: 245951, N_resample: 1000
# Rpt0 - Processing hor_15_50 with index 479
# Rpt0 - npt: 149145, N_resample: 1000
# Rpt0 - Processing hor_153_336 with index 480
# Rpt0 - npt: 226546, N_resample: 1000
# Rpt0 - Processing ver_194_38 with index 481
# Rpt0 - npt: 215459, N_resample: 1000
# Rpt0 - Processing dia_417_171 with index 482
# Rpt0 - npt: 257786, N_resample: 1000
# Rpt0 - Processing ver_120_122 with index 483
# Rpt0 - npt: 198053, N_resample: 1000
# Rpt0 - Processing hor_616_77 with index 484
# Rpt0 - npt: 234822, N_resample: 1000
# Rpt0 - Processing ver_153_58 with index 485
# Rpt0 - npt: 220190, N_resample: 1000
# Rpt0 - Processing ver_323_560 with index 486
# Rpt0 - npt: 159353, N_resample: 1000
# Rpt0 - Processing hor_497_257 with index 487
# Rpt0 - npt: 170128, N_resample: 1000
# Rpt0 - Processing hor_149_86 with index 488
# Rpt0 - npt: 267378, N_resample: 1000
# Rpt0 - Processing dia_616_77 with index 489
# Rpt0 - npt: 234822, N_resample: 1000
# Rpt0 - Processing dia_322_280 with index 490
# Rpt0 - npt: 189155, N_resample: 1000
# Rpt0 - Processing hor_86_371 with index 491
# Rpt0 - npt: 219933, N_resample: 1000
# Rpt0 - Processing ver_268_289 with index 492
# Rpt0 - npt: 222623, N_resample: 1000
# Rpt0 - Processing dia_58_8 with index 493
# Rpt0 - npt: 203878, N_resample: 1000
# Rpt0 - Processing ver_174_114 with index 494
# Rpt0 - npt: 196695, N_resample: 1000
# Rpt0 - Processing hor_77_234 with index 495
# Rpt0 - npt: 224900, N_resample: 1000
# Rpt0 - Processing dia_214_616 with index 496
# Rpt0 - npt: 245552, N_resample: 1000
# Rpt0 - Processing hor_142_605 with index 497
# Rpt0 - npt: 189548, N_resample: 1000
# Rpt0 - Processing ver_20_483 with index 498
# Rpt0 - npt: 164991, N_resample: 1000
# Rpt0 - Processing dia_377_72 with index 499
# Rpt0 - npt: 237781, N_resample: 1000
# Rpt0 - Processing ver_55_87 with index 500
# Rpt0 - npt: 195530, N_resample: 1000
# Rpt0 - Processing dia_63_624 with index 501
# Rpt0 - npt: 195567, N_resample: 1000
# Rpt0 - Processing hor_181_536 with index 502
# Rpt0 - npt: 241169, N_resample: 1000
# Rpt0 - Processing dia_95_506 with index 503
# Rpt0 - npt: 151619, N_resample: 1000
# Rpt0 - Processing hor_421_21 with index 504
# Rpt0 - npt: 163898, N_resample: 1000
# Rpt0 - Processing hor_546_323 with index 505
# Rpt0 - npt: 213598, N_resample: 1000
# Rpt0 - Processing dia_633_512 with index 506
# Rpt0 - npt: 213029, N_resample: 1000
# Rpt0 - Processing dia_411_628 with index 507
# Rpt0 - npt: 209298, N_resample: 1000
# Rpt0 - Processing hor_61_125 with index 508
# Rpt0 - npt: 186992, N_resample: 1000
# Rpt0 - Processing ver_295_238 with index 509
# Rpt0 - npt: 190497, N_resample: 1000
# Rpt0 - Processing dia_77_78 with index 510
# Rpt0 - npt: 257763, N_resample: 1000
# Rpt0 - Processing dia_569_284 with index 511
# Rpt0 - npt: 246146, N_resample: 1000
# Rpt0 - Processing dia_523_323 with index 512
# Rpt0 - npt: 140609, N_resample: 1000
# Rpt0 - Processing ver_427_257 with index 513
# Rpt0 - npt: 222941, N_resample: 1000
# Rpt0 - Processing dia_377_411 with index 514
# Rpt0 - npt: 236050, N_resample: 1000
# Rpt0 - Processing dia_535_432 with index 515
# Rpt0 - npt: 299291, N_resample: 1000
# Rpt0 - Processing ver_290_16 with index 516
# Rpt0 - npt: 173245, N_resample: 1000
# Rpt0 - Processing ver_8_489 with index 517
# Rpt0 - npt: 151362, N_resample: 1000
# Rpt0 - Processing dia_123_114 with index 518
# Rpt0 - npt: 227112, N_resample: 1000
# Rpt0 - Processing hor_289_87 with index 519
# Rpt0 - npt: 226479, N_resample: 1000
# Rpt0 - Processing hor_296_375 with index 520
# Rpt0 - npt: 232404, N_resample: 1000
# Rpt0 - Processing hor_389_479 with index 521
# Rpt0 - npt: 137295, N_resample: 1000
# Rpt0 - Processing hor_569_257 with index 522
# Rpt0 - npt: 186352, N_resample: 1000
# Rpt0 - Processing dia_434_511 with index 523
# Rpt0 - npt: 201138, N_resample: 1000
# Rpt0 - Processing ver_142_80 with index 524
# Rpt0 - npt: 188814, N_resample: 1000
# Rpt0 - Processing hor_424_395 with index 525
# Rpt0 - npt: 298222, N_resample: 1000
# Rpt0 - Processing hor_267_616 with index 526
# Rpt0 - npt: 226152, N_resample: 1000
# Rpt0 - Processing ver_61_79 with index 527
# Rpt0 - npt: 233562, N_resample: 1000
# Rpt0 - Processing dia_131_27 with index 528
# Rpt0 - npt: 225489, N_resample: 1000
# Rpt0 - Processing hor_209_302 with index 529
# Rpt0 - npt: 245327, N_resample: 1000
# Rpt0 - Processing dia_319_527 with index 530
# Rpt0 - npt: 311813, N_resample: 1000
# Rpt0 - Processing hor_82_233 with index 531
# Rpt0 - npt: 230075, N_resample: 1000
# Rpt0 - Processing ver_249_270 with index 532
# Rpt0 - npt: 163593, N_resample: 1000
# Rpt0 - Processing ver_50_361 with index 533
# Rpt0 - npt: 146258, N_resample: 1000
# Rpt0 - Processing hor_417_342 with index 534
# Rpt0 - npt: 185050, N_resample: 1000
# Rpt0 - Processing dia_191_77 with index 535
# Rpt0 - npt: 297150, N_resample: 1000
# Rpt0 - Processing hor_605_323 with index 536
# Rpt0 - npt: 145325, N_resample: 1000
# Rpt0 - Processing ver_440_510 with index 537
# Rpt0 - npt: 178019, N_resample: 1000
# Rpt0 - Processing hor_125_565 with index 538
# Rpt0 - npt: 167075, N_resample: 1000
# Rpt0 - Processing dia_14_107 with index 539
# Rpt0 - npt: 195912, N_resample: 1000
# Rpt0 - Processing dia_524_95 with index 540
# Rpt0 - npt: 157542, N_resample: 1000
# Rpt0 - Processing dia_497_240 with index 541
# Rpt0 - npt: 185969, N_resample: 1000
# Rpt0 - Processing dia_245_624 with index 542
# Rpt0 - npt: 199913, N_resample: 1000
# Rpt0 - Processing ver_16_320 with index 543
# Rpt0 - npt: 161366, N_resample: 1000
# Rpt0 - Processing hor_454_28 with index 544
# Rpt0 - npt: 210588, N_resample: 1000
# Rpt0 - Processing dia_21_25 with index 545
# Rpt0 - npt: 127970, N_resample: 1000
# Rpt0 - Processing hor_329_194 with index 546
# Rpt0 - npt: 284972, N_resample: 1000
# Rpt0 - Processing hor_499_206 with index 547
# Rpt0 - npt: 208493, N_resample: 1000
# Rpt0 - Processing ver_564_523 with index 548
# Rpt0 - npt: 172139, N_resample: 1000
# Rpt0 - Processing hor_427_170 with index 549
# Rpt0 - npt: 281627, N_resample: 1000
# Rpt0 - Processing dia_125_302 with index 550
# Rpt0 - npt: 170269, N_resample: 1000
# Rpt0 - Processing ver_62_394 with index 551
# Rpt0 - npt: 270512, N_resample: 1000
# Rpt0 - Processing hor_66_20 with index 552
# Rpt0 - npt: 207927, N_resample: 1000
# Rpt0 - Processing ver_122_214 with index 553
# Rpt0 - npt: 216328, N_resample: 1000
# Rpt0 - Processing dia_199_91 with index 554
# Rpt0 - npt: 197776, N_resample: 1000
# Rpt0 - Processing ver_492_209 with index 555
# Rpt0 - npt: 248313, N_resample: 1000
# Rpt0 - Processing hor_257_485 with index 556
# Rpt0 - npt: 207350, N_resample: 1000
# Rpt0 - Processing ver_572_256 with index 557
# Rpt0 - npt: 180950, N_resample: 1000
# Rpt0 - Processing hor_241_549 with index 558
# Rpt0 - npt: 234450, N_resample: 1000
# Rpt0 - Processing dia_21_119 with index 559
# Rpt0 - npt: 216493, N_resample: 1000
# Rpt0 - Processing dia_439_319 with index 560
# Rpt0 - npt: 250778, N_resample: 1000
# Rpt0 - Processing ver_211_590 with index 561
# Rpt0 - npt: 218388, N_resample: 1000
# Rpt0 - Processing hor_623_492 with index 562
# Rpt0 - npt: 179201, N_resample: 1000
# Rpt0 - Processing dia_257_456 with index 563
# Rpt0 - npt: 172820, N_resample: 1000
# Rpt0 - Processing hor_473_388 with index 564
# Rpt0 - npt: 168079, N_resample: 1000
# Rpt0 - Processing dia_202_77 with index 565
# Rpt0 - npt: 173089, N_resample: 1000
# Rpt0 - Processing ver_524_56 with index 566
# Rpt0 - npt: 182440, N_resample: 1000
# Rpt0 - Processing dia_59_576 with index 567
# Rpt0 - npt: 140937, N_resample: 1000
# Rpt0 - Processing hor_173_483 with index 568
# Rpt0 - npt: 203500, N_resample: 1000
# Rpt0 - Processing ver_195_440 with index 569
# Rpt0 - npt: 200903, N_resample: 1000
# Rpt0 - Processing ver_240_249 with index 570
# Rpt0 - npt: 190091, N_resample: 1000
# Rpt0 - Processing ver_418_200 with index 571
# Rpt0 - npt: 260713, N_resample: 1000
# Rpt0 - Processing hor_245_484 with index 572
# Rpt0 - npt: 192776, N_resample: 1000
# Rpt0 - Processing dia_322_6 with index 573
# Rpt0 - npt: 184431, N_resample: 1000
# Rpt0 - Processing dia_211_572 with index 574
# Rpt0 - npt: 213773, N_resample: 1000
# Rpt0 - Processing dia_616_415 with index 575
# Rpt0 - npt: 202753, N_resample: 1000
# Rpt0 - Processing ver_524_320 with index 576
# Rpt0 - npt: 168036, N_resample: 1000
# Rpt0 - Processing hor_523_519 with index 577
# Rpt0 - npt: 168182, N_resample: 1000
# Rpt0 - Processing dia_507_255 with index 578
# Rpt0 - npt: 176585, N_resample: 1000
# Rpt0 - Processing ver_56_50 with index 579
# Rpt0 - npt: 181142, N_resample: 1000
# Rpt0 - Processing ver_142_233 with index 580
# Rpt0 - npt: 241962, N_resample: 1000
# Rpt0 - Processing dia_439_460 with index 581
# Rpt0 - npt: 235223, N_resample: 1000
# Rpt0 - Processing ver_449_114 with index 582
# Rpt0 - npt: 249102, N_resample: 1000
# Rpt0 - Processing hor_291_474 with index 583
# Rpt0 - npt: 265704, N_resample: 1000
# Rpt0 - Processing dia_123_59 with index 584
# Rpt0 - npt: 194494, N_resample: 1000
# Rpt0 - Processing dia_139_107 with index 585
# Rpt0 - npt: 205946, N_resample: 1000
# Rpt0 - Processing dia_459_484 with index 586
# Rpt0 - npt: 216342, N_resample: 1000
# ...
# Rpt0 - npt: 189675, N_resample: 1000
# Rpt0 - Processing ver_421_448 with index 6123
# Rpt0 - npt: 155985, N_resample: 1000
# Rpt0 - Processing ver_247_35 with index 6124
# Rpt0 - npt: 196174, N_resample: 1000
# Rpt0 - Processing dia_202_221 with index 6125
# Rpt0 - npt: 164152, N_resample: 1000
# Rpt0 - Processing dia_494_122 with index 6126
# Rpt0 - npt: 174847, N_resample: 1000
# Rpt0 - Processing ver_50_380 with index 6127
# Rpt0 - npt: 212721, N_resample: 1000
# Rpt0 - Processing hor_6_351 with index 6128
# Rpt0 - npt: 243019, N_resample: 1000
# Rpt0 - Processing hor_270_497 with index 6129
# Rpt0 - npt: 163245, N_resample: 1000
# Rpt0 - Processing hor_50_380 with index 6130
# Rpt0 - npt: 212721, N_resample: 1000
# Rpt0 - Processing hor_406_207 with index 6131
# Rpt0 - npt: 187023, N_resample: 1000
# Rpt0 - Processing ver_322_114 with index 6132
# Rpt0 - npt: 163216, N_resample: 1000
# Rpt0 - Processing ver_424_322 with index 6133
# Rpt0 - npt: 194685, N_resample: 1000
# Rpt0 - Processing ver_138_79 with index 6134
# Rpt0 - npt: 316616, N_resample: 1000
# Rpt0 - Processing hor_147_492 with index 6135
# Rpt0 - npt: 224655, N_resample: 1000
# Rpt0 - Processing dia_280_202 with index 6136
# Rpt0 - npt: 183590, N_resample: 1000
# Rpt0 - Processing hor_371_249 with index 6137
# Rpt0 - npt: 192484, N_resample: 1000
# Rpt0 - Processing ver_182_417 with index 6138
# Rpt0 - npt: 218102, N_resample: 1000
# Rpt0 - Processing dia_492_275 with index 6139
# Rpt0 - npt: 216513, N_resample: 1000
# Rpt0 - Processing dia_153_323 with index 6140
# Rpt0 - npt: 169007, N_resample: 1000
# Rpt0 - Processing hor_438_266 with index 6141
# Rpt0 - npt: 273415, N_resample: 1000
# Rpt0 - Processing ver_565_322 with index 6142
# Rpt0 - npt: 174232, N_resample: 1000
# Rpt0 - Processing dia_291_348 with index 6143
# Rpt0 - npt: 214314, N_resample: 1000
# Rpt0 - Processing ver_479_122 with index 6144
# Rpt0 - npt: 151574, N_resample: 1000
# Rpt0 - Processing hor_625_546 with index 6145
# Rpt0 - npt: 210118, N_resample: 1000
# Rpt0 - Processing dia_131_187 with index 6146
# Rpt0 - npt: 221718, N_resample: 1000
# Rpt0 - Processing hor_56_95 with index 6147
# Rpt0 - npt: 230454, N_resample: 1000
# Rpt0 - Processing hor_411_72 with index 6148
# Rpt0 - npt: 259543, N_resample: 1000
# Rpt0 - Processing ver_438_375 with index 6149
# Rpt0 - npt: 294678, N_resample: 1000
# Rpt0 - Processing ver_476_438 with index 6150
# Rpt0 - npt: 294098, N_resample: 1000
# Rpt0 - Processing hor_200_506 with index 6151
# Rpt0 - npt: 159739, N_resample: 1000
# Rpt0 - Processing ver_55_256 with index 6152
# Rpt0 - npt: 168276, N_resample: 1000
# Rpt0 - Processing ver_241_494 with index 6153
# Rpt0 - npt: 205331, N_resample: 1000
# Rpt0 - Processing hor_572_202 with index 6154
# Rpt0 - npt: 156428, N_resample: 1000
# Rpt0 - Processing ver_377_339 with index 6155
# Rpt0 - npt: 200991, N_resample: 1000
# Rpt0 - Processing ver_384_331 with index 6156
# Rpt0 - npt: 236573, N_resample: 1000
# Rpt0 - Processing dia_122_342 with index 6157
# Rpt0 - npt: 178304, N_resample: 1000
# Rpt0 - Processing hor_590_511 with index 6158
# Rpt0 - npt: 145837, N_resample: 1000
# Rpt0 - Processing dia_440_211 with index 6159
# Rpt0 - npt: 213918, N_resample: 1000
# Rpt0 - Processing dia_66_206 with index 6160
# Rpt0 - npt: 231261, N_resample: 1000
# Rpt0 - Processing dia_415_280 with index 6161
# Rpt0 - npt: 204734, N_resample: 1000
# Rpt0 - Processing ver_565_79 with index 6162
# Rpt0 - npt: 325623, N_resample: 1000
# Rpt0 - Processing ver_556_21 with index 6163
# Rpt0 - npt: 140186, N_resample: 1000
# Rpt0 - Processing hor_91_390 with index 6164
# Rpt0 - npt: 170175, N_resample: 1000
# Rpt0 - Processing ver_101_78 with index 6165
# Rpt0 - npt: 192353, N_resample: 1000
# Rpt0 - Processing hor_511_280 with index 6166
# Rpt0 - npt: 196923, N_resample: 1000
# Rpt0 - Processing hor_403_107 with index 6167
# Rpt0 - npt: 266631, N_resample: 1000
# Rpt0 - Processing ver_329_473 with index 6168
# Rpt0 - npt: 179445, N_resample: 1000
# Rpt0 - Processing ver_611_275 with index 6169
# Rpt0 - npt: 163434, N_resample: 1000
# Rpt0 - Processing dia_499_206 with index 6170
# Rpt0 - npt: 208493, N_resample: 1000
# Rpt0 - Processing ver_131_523 with index 6171
# Rpt0 - npt: 206197, N_resample: 1000
# Rpt0 - Processing ver_488_220 with index 6172
# Rpt0 - npt: 217580, N_resample: 1000
# Rpt0 - Processing ver_465_270 with index 6173
# Rpt0 - npt: 208039, N_resample: 1000
# Rpt0 - Processing dia_247_488 with index 6174
# Rpt0 - npt: 213206, N_resample: 1000
# Rpt0 - Processing ver_245_221 with index 6175
# Rpt0 - npt: 192968, N_resample: 1000
# Rpt0 - Processing hor_241_550 with index 6176
# Rpt0 - npt: 231429, N_resample: 1000
# Rpt0 - Processing hor_507_241 with index 6177
# Rpt0 - npt: 165047, N_resample: 1000
# Rpt0 - Processing dia_448_485 with index 6178
# Rpt0 - npt: 173602, N_resample: 1000
# Rpt0 - Processing ver_400_153 with index 6179
# Rpt0 - npt: 158606, N_resample: 1000
# Rpt0 - Processing dia_267_564 with index 6180
# Rpt0 - npt: 198614, N_resample: 1000
# Rpt0 - Processing hor_229_345 with index 6181
# Rpt0 - npt: 245840, N_resample: 1000
# Rpt0 - Processing dia_199_329 with index 6182
# Rpt0 - npt: 216984, N_resample: 1000
# Rpt0 - Processing hor_466_25 with index 6183
# Rpt0 - npt: 142794, N_resample: 1000
# Rpt0 - Processing hor_72_630 with index 6184
# Rpt0 - npt: 175276, N_resample: 1000
# Rpt0 - Processing hor_249_546 with index 6185
# Rpt0 - npt: 224731, N_resample: 1000
# Rpt0 - Processing dia_377_339 with index 6186
# Rpt0 - npt: 200991, N_resample: 1000
# Rpt0 - Processing dia_331_624 with index 6187
# Rpt0 - npt: 209902, N_resample: 1000
# Rpt0 - Processing dia_428_269 with index 6188
# Rpt0 - npt: 349128, N_resample: 1000
# Rpt0 - Processing ver_173_6 with index 6189
# Rpt0 - npt: 232429, N_resample: 1000
# Rpt0 - Processing hor_524_427 with index 6190
# Rpt0 - npt: 187627, N_resample: 1000
# Rpt0 - Processing hor_466_615 with index 6191
# Rpt0 - npt: 205001, N_resample: 1000
# Rpt0 - Processing ver_565_421 with index 6192
# Rpt0 - npt: 200861, N_resample: 1000
# Rpt0 - Processing hor_624_170 with index 6193
# Rpt0 - npt: 223436, N_resample: 1000
# Rpt0 - Processing dia_56_21 with index 6194
# Rpt0 - npt: 180977, N_resample: 1000
# Rpt0 - Processing ver_466_248 with index 6195
# Rpt0 - npt: 208936, N_resample: 1000
# Rpt0 - Processing ver_406_207 with index 6196
# Rpt0 - npt: 187023, N_resample: 1000
# Rpt0 - Processing ver_519_389 with index 6197
# Rpt0 - npt: 182719, N_resample: 1000
# Rpt0 - Processing ver_630_139 with index 6198
# Rpt0 - npt: 180378, N_resample: 1000
# Rpt0 - Processing dia_488_415 with index 6199
# Rpt0 - npt: 184451, N_resample: 1000
# Rpt0 - Processing ver_173_119 with index 6200
# Rpt0 - npt: 240498, N_resample: 1000
# Rpt0 - Processing ver_16_576 with index 6201
# Rpt0 - npt: 142216, N_resample: 1000
# Rpt0 - Processing hor_147_249 with index 6202
# Rpt0 - npt: 170109, N_resample: 1000
# Rpt0 - Processing ver_441_537 with index 6203
# Rpt0 - npt: 252880, N_resample: 1000
# Rpt0 - Processing ver_506_625 with index 6204
# Rpt0 - npt: 132019, N_resample: 1000
# Rpt0 - Processing ver_245_101 with index 6205
# Rpt0 - npt: 207477, N_resample: 1000
# Rpt0 - Processing ver_546_245 with index 6206
# Rpt0 - npt: 240367, N_resample: 1000
# Rpt0 - Processing ver_548_233 with index 6207
# Rpt0 - npt: 215199, N_resample: 1000
# Rpt0 - Processing hor_285_139 with index 6208
# Rpt0 - npt: 204522, N_resample: 1000
# Rpt0 - Processing ver_536_213 with index 6209
# Rpt0 - npt: 203786, N_resample: 1000
# Rpt0 - Processing dia_174_138 with index 6210
# Rpt0 - npt: 210364, N_resample: 1000
# Rpt0 - Processing ver_615_342 with index 6211
# Rpt0 - npt: 211092, N_resample: 1000
# Rpt0 - Processing ver_535_27 with index 6212
# Rpt0 - npt: 246156, N_resample: 1000
# Rpt0 - Processing hor_615_351 with index 6213
# Rpt0 - npt: 243084, N_resample: 1000
# Rpt0 - Processing hor_447_202 with index 6214
# Rpt0 - npt: 151313, N_resample: 1000
# Rpt0 - Processing dia_61_433 with index 6215
# Rpt0 - npt: 226538, N_resample: 1000
# Rpt0 - Processing dia_536_536 with index 6216
# Rpt0 - npt: 145595, N_resample: 1000
# Rpt0 - Processing ver_519_77 with index 6217
# Rpt0 - npt: 220859, N_resample: 1000
# Rpt0 - Processing ver_77_10 with index 6218
# Rpt0 - npt: 238739, N_resample: 1000
# Rpt0 - Processing ver_146_28 with index 6219
# Rpt0 - npt: 240979, N_resample: 1000
# Rpt0 - Processing dia_182_345 with index 6220
# Rpt0 - npt: 281763, N_resample: 1000
# Rpt0 - Processing hor_377_257 with index 6221
# Rpt0 - npt: 207459, N_resample: 1000
# Rpt0 - Processing ver_415_200 with index 6222
# Rpt0 - npt: 186915, N_resample: 1000
# Rpt0 - Processing dia_248_625 with index 6223
# Rpt0 - npt: 186735, N_resample: 1000
# Rpt0 - Processing hor_615_454 with index 6224
# Rpt0 - npt: 194716, N_resample: 1000
# Rpt0 - Processing hor_319_564 with index 6225
# Rpt0 - npt: 224579, N_resample: 1000
# Rpt0 - Processing hor_433_81 with index 6226
# Rpt0 - npt: 168783, N_resample: 1000
# Rpt0 - Processing dia_208_102 with index 6227
# Rpt0 - npt: 225022, N_resample: 1000
# Rpt0 - Processing ver_125_625 with index 6228
# Rpt0 - npt: 151438, N_resample: 1000
# Rpt0 - Processing dia_284_378 with index 6229
# Rpt0 - npt: 224522, N_resample: 1000
# Rpt0 - Processing dia_519_390 with index 6230
# Rpt0 - npt: 180904, N_resample: 1000
# Rpt0 - Processing hor_125_625 with index 6231
# Rpt0 - npt: 151438, N_resample: 1000
# Rpt0 - Processing dia_456_9 with index 6232
# Rpt0 - npt: 166386, N_resample: 1000
# Rpt0 - Processing hor_342_217 with index 6233
# Rpt0 - npt: 221381, N_resample: 1000
# Rpt0 - Processing ver_20_575 with index 6234
# Rpt0 - npt: 178438, N_resample: 1000
# Rpt0 - Processing dia_291_257 with index 6235
# Rpt0 - npt: 201334, N_resample: 1000
# Rpt0 - Processing hor_548_234 with index 6236
# Rpt0 - npt: 237763, N_resample: 1000
# Rpt0 - Processing hor_616_556 with index 6237
# Rpt0 - npt: 196472, N_resample: 1000
# Rpt0 - Processing ver_560_456 with index 6238
# Rpt0 - npt: 173658, N_resample: 1000
# Rpt0 - Processing ver_129_400 with index 6239
# Rpt0 - npt: 190011, N_resample: 1000
# Rpt0 - Processing ver_323_87 with index 6240
# Rpt0 - npt: 192917, N_resample: 1000
# Rpt0 - Processing hor_630_441 with index 6241
# Rpt0 - npt: 189855, N_resample: 1000
# Rpt0 - Processing dia_449_291 with index 6242
# Rpt0 - npt: 278292, N_resample: 1000
# Rpt0 - Processing ver_206_107 with index 6243
# Rpt0 - npt: 213985, N_resample: 1000
# Rpt0 - Processing dia_489_153 with index 6244
# Rpt0 - npt: 183358, N_resample: 1000
# Rpt0 - Processing ver_38_249 with index 6245
# Rpt0 - npt: 171170, N_resample: 1000
# Rpt0 - Processing hor_255_20 with index 6246
# Rpt0 - npt: 213691, N_resample: 1000
# Rpt0 - Processing ver_35_377 with index 6247
# Rpt0 - npt: 186255, N_resample: 1000
# Rpt0 - Processing hor_275_91 with index 6248
# Rpt0 - npt: 186586, N_resample: 1000
# Rpt0 - Processing hor_586_406 with index 6249
# Rpt0 - npt: 165483, N_resample: 1000
# Rpt0 - Processing hor_61_257 with index 6250
# Rpt0 - npt: 203244, N_resample: 1000
# Rpt0 - Processing dia_415_14 with index 6251
# Rpt0 - npt: 199493, N_resample: 1000
# Rpt0 - Processing hor_378_198 with index 6252
# Rpt0 - npt: 272418, N_resample: 1000
# Rpt0 - Processing dia_55_320 with index 6253
# Rpt0 - npt: 178257, N_resample: 1000
# Rpt0 - Processing dia_339_214 with index 6254
# Rpt0 - npt: 198969, N_resample: 1000
# Rpt0 - Processing hor_506_316 with index 6255
# Rpt0 - npt: 166722, N_resample: 1000
# Rpt0 - Processing hor_394_238 with index 6256
# Rpt0 - npt: 245490, N_resample: 1000
# Rpt0 - Processing dia_513_249 with index 6257
# Rpt0 - npt: 183948, N_resample: 1000
# Rpt0 - Processing dia_415_200 with index 6258
# Rpt0 - npt: 186915, N_resample: 1000
# Rpt0 - Processing hor_270_173 with index 6259
# Rpt0 - npt: 194696, N_resample: 1000
# Rpt0 - Processing hor_329_148 with index 6260
# Rpt0 - npt: 205445, N_resample: 1000
# Rpt0 - Processing ver_199_427 with index 6261
# Rpt0 - npt: 255516, N_resample: 1000
# Rpt0 - Processing hor_25_12 with index 6262
# Rpt0 - npt: 141244, N_resample: 1000
# Rpt0 - Processing dia_66_572 with index 6263
# Rpt0 - npt: 182795, N_resample: 1000
# Rpt0 - Processing ver_548_211 with index 6264
# Rpt0 - npt: 233080, N_resample: 1000
# Rpt0 - Processing ver_8_21 with index 6265
# Rpt0 - npt: 139774, N_resample: 1000
# Rpt0 - Processing hor_466_488 with index 6266
# Rpt0 - npt: 172861, N_resample: 1000
# Rpt0 - Processing ver_331_624 with index 6267
# Rpt0 - npt: 209902, N_resample: 1000
# Rpt0 - Processing dia_630_459 with index 6268
# Rpt0 - npt: 160445, N_resample: 1000
# Rpt0 - Processing ver_173_113 with index 6269
# Rpt0 - npt: 233146, N_resample: 1000
# Rpt0 - Processing ver_592_79 with index 6270
# Rpt0 - npt: 239490, N_resample: 1000
# Rpt0 - Processing dia_351_460 with index 6271
# Rpt0 - npt: 226783, N_resample: 1000
# Rpt0 - Processing ver_125_95 with index 6272
# Rpt0 - npt: 161090, N_resample: 1000
# Rpt0 - Processing ver_295_533 with index 6273
# Rpt0 - npt: 130565, N_resample: 1000
# Rpt0 - Processing dia_536_533 with index 6274
# Rpt0 - npt: 138471, N_resample: 1000
# Rpt0 - Processing dia_192_225 with index 6275
# Rpt0 - npt: 269427, N_resample: 1000
# Rpt0 - Processing ver_35_342 with index 6276
# Rpt0 - npt: 199613, N_resample: 1000
# Rpt0 - Processing dia_268_441 with index 6277
# Rpt0 - npt: 203692, N_resample: 1000
# Rpt0 - Processing ver_559_22 with index 6278
# Rpt0 - npt: 257247, N_resample: 1000
# Rpt0 - Processing hor_101_78 with index 6279
# Rpt0 - npt: 192353, N_resample: 1000
# Rpt0 - Processing ver_255_113 with index 6280
# Rpt0 - npt: 215637, N_resample: 1000
# Rpt0 - Processing hor_225_473 with index 6281
# Rpt0 - npt: 196667, N_resample: 1000
# Rpt0 - Processing ver_489_575 with index 6282
# Rpt0 - npt: 197817, N_resample: 1000
# Rpt0 - Processing dia_174_590 with index 6283
# Rpt0 - npt: 180242, N_resample: 1000
# Rpt0 - Processing dia_316_12 with index 6284
# Rpt0 - npt: 193486, N_resample: 1000
# Rpt0 - Processing dia_473_58 with index 6285
# Rpt0 - npt: 194092, N_resample: 1000
# Rpt0 - Processing ver_61_433 with index 6286
# Rpt0 - npt: 226538, N_resample: 1000
# Rpt0 - Processing ver_217_101 with index 6287
# Rpt0 - npt: 262679, N_resample: 1000
# Rpt0 - Processing dia_416_282 with index 6288
# Rpt0 - npt: 302979, N_resample: 1000
# Rpt0 - Processing hor_19_550 with index 6289
# Rpt0 - npt: 265458, N_resample: 1000
# Rpt0 - Processing ver_628_270 with index 6290
# Rpt0 - npt: 154326, N_resample: 1000
# Rpt0 - Processing hor_296_120 with index 6291
# Rpt0 - npt: 251472, N_resample: 1000
# Rpt0 - Processing hor_537_142 with index 6292
# Rpt0 - npt: 228969, N_resample: 1000
# Rpt0 - Processing hor_575_27 with index 6293
# Rpt0 - npt: 200850, N_resample: 1000
# Rpt0 - Processing ver_559_95 with index 6294
# Rpt0 - npt: 189486, N_resample: 1000
# Rpt0 - Processing hor_625_120 with index 6295
# Rpt0 - npt: 200294, N_resample: 1000
# Rpt0 - Processing hor_437_296 with index 6296
# Rpt0 - npt: 217777, N_resample: 1000
# Rpt0 - Processing hor_295_149 with index 6297
# Rpt0 - npt: 216122, N_resample: 1000
# Rpt0 - Processing dia_473_148 with index 6298
# Rpt0 - npt: 179861, N_resample: 1000
# Rpt0 - Processing hor_295_55 with index 6299
# Rpt0 - npt: 150483, N_resample: 1000
# Rpt0 - Processing hor_546_181 with index 6300
# Rpt0 - npt: 292019, N_resample: 1000
# Rpt0 - Processing ver_199_433 with index 6301
# Rpt0 - npt: 212954, N_resample: 1000
# Rpt0 - Processing ver_107_459 with index 6302
# Rpt0 - npt: 206544, N_resample: 1000
# Rpt0 - Processing ver_217_361 with index 6303
# Rpt0 - npt: 217000, N_resample: 1000
# Rpt0 - Processing ver_324_249 with index 6304
# Rpt0 - npt: 181764, N_resample: 1000
# Rpt0 - Processing dia_295_149 with index 6305
# Rpt0 - npt: 216122, N_resample: 1000
# Rpt0 - Processing hor_400_153 with index 6306
# Rpt0 - npt: 158606, N_resample: 1000
# Rpt0 - Processing ver_556_449 with index 6307
# Rpt0 - npt: 225767, N_resample: 1000
# Rpt0 - Processing ver_572_485 with index 6308
# Rpt0 - npt: 215797, N_resample: 1000
# Rpt0 - Processing dia_546_535 with index 6309
# Rpt0 - npt: 253579, N_resample: 1000
# Rpt0 - Processing ver_249_62 with index 6310
# Rpt0 - npt: 154088, N_resample: 1000
# Rpt0 - Processing dia_564_270 with index 6311
# Rpt0 - npt: 182967, N_resample: 1000
# Rpt0 - Processing dia_306_417 with index 6312
# Rpt0 - npt: 203042, N_resample: 1000
# Rpt0 - Processing hor_131_351 with index 6313
# Rpt0 - npt: 239956, N_resample: 1000
# Rpt0 - Processing dia_428_81 with index 6314
# Rpt0 - npt: 214845, N_resample: 1000
# 100%|██████████| 1/1 [00:58<00:00, 58.64s/it]

# %%
import sys, os
print(sys.executable)
print(sys.version)
print(os.getcwd())
# Out:
# /usr/bin/python
# 3.11.10 (main, Sep  7 2024, 18:35:41) [GCC 11.4.0]
# /workspace/Point-DeepONet/1.Data_preprocessing

# %% [markdown]
# ### 1.1.2 Data Visualization
#
# In this section, we visualize the resampled data by generating histograms for various stress components across different sampling parameters. The workflow includes:
#
# - **Data Loading and Clipping**: Loads the resampled datasets, applies clipping to stress values to focus on a specific range, and organizes the data based on direction and stress type.
# - **Histogram Plotting**: Creates and saves histograms for each stress component (`ux`, `uy`, `uz`, and von Mises stress) across vertical, horizontal, and diagonal directions. This helps in understanding the distribution and variability of the stress values under different sampling scenarios.
#
# By implementing these visualization steps, we gain insights into the behavior of stress measurements, ensuring that the resampling process maintains the integrity and variability of the original data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os


# Mapping for label names and their descriptive forms
label_names = ['ux', 'uy', 'uz', 'von Mises stress']
label_descriptions = {
    'ux': '$u_x$ (mm)',
    'uy': '$u_y$ (mm)',
    'uz': '$u_z$ (mm)',
    'von Mises stress': 'von Mises stress (MPa)'
}

# Mapping for direction abbreviations to full forms
direction_full = {
    'ver': 'vertical',
    'hor': 'horizontal',
    'dia': 'diagonal'
}

base_figures = '../figures/'

def clip_stress_values(data, min_val, max_val):
    """
    Clips stress values to a specified range.

    Parameters:
    - data: Numpy array of stress values.
    - min_val: Minimum value for clipping.
    - max_val: Maximum value for clipping.

    Returns:
    - Clipped numpy array.
    """
    return np.clip(data, min_val, max_val)

def plot_hist_stress(data_dict, N_resample, direction, min_clip, max_clip, label_name, target_index, base_figures):
    """
    Plots and saves histograms of stress values after clipping.

    Parameters:
    - data_dict: Dictionary containing stress data for different N_resample values.
    - N_resample: List of resample sizes.
    - direction: Direction of stress ('ver', 'hor', 'dia').
    - min_clip: Minimum clipping value.
    - max_clip: Maximum clipping value.
    - label_name: Name of the stress component.
    - target_index: Index of the stress component.
    - base_figures: Base directory to save figures.
    """
    # Get the full form of the direction
    direction_full_name = direction_full.get(direction, direction)
    
    # Get the descriptive label name
    label_description = label_descriptions.get(label_name, label_name)
    
    # Color palette
    colors = plt.get_cmap('tab10').colors

    # Create the plot
    plt.figure(figsize=(8, 6))
    for idx, n in reversed(list(enumerate(N_resample))):
        # Apply clipping
        if target_index == 3:  # For 'von Mises stress', set min_clip to 0
            clipped_data = clip_stress_values(data_dict[n], 0, max_clip)
        else:
            clipped_data = clip_stress_values(data_dict[n], min_clip, max_clip)
        
        # Plot histogram
        plt.hist(
            clipped_data, bins=50, color=colors[idx % len(colors)], 
            label=f'N={n}', alpha=0.7
        )
    
    # Set the title and labels
    plt.xlabel(label_description)  # Changed: set fontsize to 20
    plt.ylabel('Frequency')
    plt.legend(title='N_resample')

    # Save the image
    save_path = os.path.join(base_figures, f'{direction}_{label_name}.png')
    plt.savefig(save_path)
    plt.show()
    plt.close()

# Information about the files to load
base_path = '../data/sampled/'
rpt = 0
N_resample_values = [500, 1000, 2000, 5000, 10000]
base_figures = '../figures/sampling/'

# Create the image save directory if it doesn't exist
if not os.path.exists(base_figures):
    os.makedirs(base_figures)

print("Starting visualization for ver_stress(MPa), hor_stress(MPa), dia_stress(MPa)...")

# Initialize data storage by direction and target_index
data_dicts = {
    'ver': {i: {} for i in range(4)}, 
    'hor': {i: {} for i in range(4)}, 
    'dia': {i: {} for i in range(4)}
}
min_clip_dict = {i: {} for i in range(4)}
max_clip_dict = {i: {} for i in range(4)}

# Load data for each N_resample value
for N_resample in tqdm(N_resample_values):
    file_path = f'{base_path}Rpt{rpt}_N{N_resample}.npz'
    if not os.path.exists(file_path):
        print(f"File {file_path} does not exist. Skipping...")
        continue

    data = np.load(file_path)
    
    # Get the list of keys (e.g., ['ver_101_1', 'hor_101_1', 'dia_101_1'])
    keys = data['c']
    stress_data = data['b']  # 'b' represents stress data

    for direction in ['ver', 'hor', 'dia']:
        # Find indices of keys that start with the current direction
        direction_indices = [i for i, key in enumerate(keys) if key.startswith(f'{direction}_')]
        if not direction_indices:
            print(f"No data available for direction {direction} with N={N_resample}")
            continue
        
        # Extract and store stress data for each target_index
        for target_index in range(4):
            label_name = label_names[target_index]
            # Extract relevant stress data and flatten
            direction_stress_data = stress_data[direction_indices, :, target_index].reshape((-1,))
            data_dicts[direction][target_index][N_resample] = direction_stress_data

            # Calculate clipping range
            min_clip = np.percentile(direction_stress_data, 0.1)
            max_clip = np.percentile(direction_stress_data, 99.9)
            
            # For 'von Mises stress', set min_clip to 0
            if target_index == 3:
                min_clip = 0
            
            print(f'{direction.upper()} N={N_resample}, Clipping {label_name} values to range: [{min_clip}, {max_clip}]')

            # Save clipping ranges based on the first N_resample value
            if N_resample == N_resample_values[0]:
                min_clip_dict[target_index][direction] = min_clip
                max_clip_dict[target_index][direction] = max_clip

# Perform visualization for each direction and label after clipping
for target_index in range(4):
    label_name = label_names[target_index]
    for direction in ['ver', 'hor', 'dia']:
        # Check if data exists for the current direction and label
        if direction not in data_dicts or target_index not in data_dicts[direction]:
            print(f"No data to visualize for direction {direction} and label {label_name}")
            continue

        print(f"Visualizing and Saving {direction} Data for {label_name} After Clipping...")
        plot_hist_stress(
            data_dicts[direction][target_index], 
            N_resample_values, 
            direction, 
            min_clip_dict[target_index].get(direction, None), 
            max_clip_dict[target_index].get(direction, None), 
            label_name, 
            target_index, 
            base_figures
        )

print("Visualization and saving completed.")
# Out:
# Starting visualization for ver_stress(MPa), hor_stress(MPa), dia_stress(MPa)...
#   0%|          | 0/5 [00:00<?, ?it/s]
# VER N=500, Clipping ux values to range: [-0.15146854150295258, 1.2512194429638333]
# VER N=500, Clipping uy values to range: [-0.2028870406448841, 0.1684320752918848]
# VER N=500, Clipping uz values to range: [-0.07288903617858887, 2.3063587808609345]
# VER N=500, Clipping von Mises stress values to range: [0, 263.847458007815]
# HOR N=500, Clipping ux values to range: [-0.8571251280903817, 0.036642064079652786]
# HOR N=500, Clipping uy values to range: [-0.052076520912349225, 0.058686037361628085]
# HOR N=500, Clipping uz values to range: [-0.7508258195519447, 0.223218013420703]
# HOR N=500, Clipping von Mises stress values to range: [0, 258.4129714965833]
#  20%|██        | 1/5 [00:00<00:03,  1.28it/s]
# DIA N=500, Clipping ux values to range: [-0.1270235081911087, 0.04470900087431106]
# DIA N=500, Clipping uy values to range: [-0.12293050166219473, 0.12342950256168891]
# DIA N=500, Clipping uz values to range: [-0.013593999668955803, 0.2798345218896887]
# DIA N=500, Clipping von Mises stress values to range: [0, 241.36744079590244]
# VER N=1000, Clipping ux values to range: [-0.15180599889159202, 1.25481909251214]
# VER N=1000, Clipping uy values to range: [-0.20271900495886802, 0.16878107839824097]
# VER N=1000, Clipping uz values to range: [-0.07375601388514041, 2.2909579739572257]
# VER N=1000, Clipping von Mises stress values to range: [0, 263.9966142578128]
# HOR N=1000, Clipping ux values to range: [-0.8587221555113792, 0.03619800435379197]
# HOR N=1000, Clipping uy values to range: [-0.0519170186035335, 0.05882600249722649]
# HOR N=1000, Clipping uz values to range: [-0.7474001348018646, 0.2227299988567834]
# HOR N=1000, Clipping von Mises stress values to range: [0, 257.9930756225591]
#  40%|████      | 2/5 [00:02<00:03,  1.28s/it]
# DIA N=1000, Clipping ux values to range: [-0.1264640043824911, 0.04493800377845797]
# DIA N=1000, Clipping uy values to range: [-0.12394601461291313, 0.12356603465229814]
# DIA N=1000, Clipping uz values to range: [-0.013674000278115273, 0.27993008452655344]
# DIA N=1000, Clipping von Mises stress values to range: [0, 241.39912815857]
# VER N=2000, Clipping ux values to range: [-0.15227000814676284, 1.261129996299747]
# VER N=2000, Clipping uy values to range: [-0.2027670025974512, 0.16773300072550806]
# VER N=2000, Clipping uz values to range: [-0.07384000173211097, 2.29002412605287]
# VER N=2000, Clipping von Mises stress values to range: [0, 263.82819003295964]
# HOR N=2000, Clipping ux values to range: [-0.860175326526165, 0.036357004471123874]
# HOR N=2000, Clipping uy values to range: [-0.05211801164224744, 0.05882600249722649]
# HOR N=2000, Clipping uz values to range: [-0.7442970915436745, 0.22369200791418684]
# HOR N=2000, Clipping von Mises stress values to range: [0, 258.1902503051764]
# DIA N=2000, Clipping ux values to range: [-0.12701700927317142, 0.04484300043061392]
# DIA N=2000, Clipping uy values to range: [-0.12416001319140196, 0.12315601065009947]
#  60%|██████    | 3/5 [00:05<00:04,  2.18s/it]
# DIA N=2000, Clipping uz values to range: [-0.01359900094009936, 0.27940300607681356]
# DIA N=2000, Clipping von Mises stress values to range: [0, 241.48842533874623]
# VER N=5000, Clipping ux values to range: [-0.15194599431753159, 1.2569710645676935]
# VER N=5000, Clipping uy values to range: [-0.20352600514888763, 0.16816499829292297]
# VER N=5000, Clipping uz values to range: [-0.0742320061326027, 2.2851901063919087]
# VER N=5000, Clipping von Mises stress values to range: [0, 263.9591676025393]
# HOR N=5000, Clipping ux values to range: [-0.8589060070514679, 0.0360430004782995]
# HOR N=5000, Clipping uy values to range: [-0.05197900360822678, 0.058562001351271153]
# HOR N=5000, Clipping uz values to range: [-0.7479670177698136, 0.22263901846115686]
# HOR N=5000, Clipping von Mises stress values to range: [0, 257.9386945495694]
# DIA N=5000, Clipping ux values to range: [-0.1273350000679493, 0.04496299948170984]
# DIA N=5000, Clipping uy values to range: [-0.12401800058037042, 0.12330300460756027]
# DIA N=5000, Clipping uz values to range: [-0.013609999790787697, 0.27924800619484413]
#  80%|████████  | 4/5 [00:13<00:04,  4.55s/it]
# DIA N=5000, Clipping von Mises stress values to range: [0, 241.46325756836086]
# VER N=10000, Clipping ux values to range: [-0.1519480069577694, 1.2609620114564937]
# VER N=10000, Clipping uy values to range: [-0.2035120010524988, 0.16811500689387726]
# VER N=10000, Clipping uz values to range: [-0.07427699963748455, 2.296904100894956]
# VER N=10000, Clipping von Mises stress values to range: [0, 264.26318447876156]
# HOR N=10000, Clipping ux values to range: [-0.8584540350437164, 0.03596799820661545]
# HOR N=10000, Clipping uy values to range: [-0.05207900058105588, 0.05832300162688303]
# HOR N=10000, Clipping uz values to range: [-0.7456799815893174, 0.2225829978883307]
# HOR N=10000, Clipping von Mises stress values to range: [0, 257.6919267272983]
# DIA N=10000, Clipping ux values to range: [-0.1273179968446493, 0.04488300159573555]
# DIA N=10000, Clipping uy values to range: [-0.12401800058037042, 0.12318500131368637]
# DIA N=10000, Clipping uz values to range: [-0.013620001331903041, 0.27966299653053284]
# 100%|██████████| 5/5 [00:30<00:00,  6.03s/it]
# DIA N=10000, Clipping von Mises stress values to range: [0, 241.4698185119637]
# Visualizing and Saving ver Data for ux After Clipping...
# Visualizing and Saving hor Data for ux After Clipping...
# Visualizing and Saving dia Data for ux After Clipping...
# Visualizing and Saving ver Data for uy After Clipping...
# Visualizing and Saving hor Data for uy After Clipping...
# Visualizing and Saving dia Data for uy After Clipping...
# Visualizing and Saving ver Data for uz After Clipping...
# Visualizing and Saving hor Data for uz After Clipping...
# Visualizing and Saving dia Data for uz After Clipping...
# Visualizing and Saving ver Data for von Mises stress After Clipping...
# Visualizing and Saving hor Data for von Mises stress After Clipping...
# Visualizing and Saving dia Data for von Mises stress After Clipping...
# Visualization and saving completed.
